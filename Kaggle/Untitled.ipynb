# %%
from selenium import webdriver
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-93833772b63f> in <module>
# ----> 1 from selenium import webdriver
#
# ModuleNotFoundError: No module named 'selenium'
