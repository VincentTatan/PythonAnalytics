# %% [markdown]
# # Value Investing Program
# # Introduction
#
# Inspired by Sean Seah Book -- Gone Fishing with Warren Buffetthttp://www.aceprofitsacademy.com/wp-content/uploads/2016/09/Gone-Fishing-with-Buffett.pdf
#
# In here we are going to try to scrape financial data:
# Input: List of the companies
#
# Web scraping:
# * Find the shareprice by year and the following metrics:
#     * EPS
#     * ROE
#     * ROA
#     * Long term debt
#     * Total Income
#     * Debt to Equity
#     * Interest Coverage Ratio
#
# Methods:
# * Given list of the companies, find out the feasibility to invest
#     * Been in market minimal 10 years
#     * Have the track records (EPS per year)
#     * Have efficiency (ROE > 15%) -- Net income / shareholder equity
#     * Determine manipulation (ROA > 7%) -- Net income / Total Asset
#     * Have small long term debt (Long term debt <5* total income)
#     * Low Debt to Equity
#     * Ability to pay interest: (Interest Coverage Ratio >3) -- EBIT / Interest expenses
#
# Outputs:
# * Ranking of each company in terms of return rate given the value investing methodology
#     * Find EPS Annual Compounded Growth Rate
#     * Estimate EPS 10 years from now
#     * Estimate stock price 10 years from now (Stock Price EPS * Average PE)
#     * Determine target by price today based on returns(discount rate 15%/20%)
#     * Add margin of safety (Safety net 15%)
#
# Additional:
# * Qualitative Assessment of the companies
#     * Advantages in business (product differentiation, branding, low price producer, high switching cost, legal barriers to entry)
#     * Ability of foolhardy management (even a fool can run)
#     * Avoid price competitive business

# %% [markdown]
# # Web scraping

# %% [markdown]
# ## Scraping Wikipedia SP500 Data Using Beautiful Soup

# %%
import bs4 as bs
import pickle
import requests

# This will keep tickers + gics industries & sub industries
def save_sp500_stocks_info():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    stocks_info=[]
    tickers = []
    securities = []
    gics_industries = []
    gics_sub_industries = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        security = row.findAll('td')[1].text
        gics_industry = row.findAll('td')[3].text
        gics_sub_industry = row.findAll('td')[4].text

        tickers.append(ticker.lower())
        securities.append(security)
        gics_industries.append(gics_industry.lower())
        gics_sub_industries.append(gics_sub_industry.lower())
    
    stocks_info.append(tickers)
    stocks_info.append(securities)
    stocks_info.append(gics_industries)
    stocks_info.append(gics_sub_industries)
    return stocks_info

stocks_info = save_sp500_stocks_info()
stocks_info_df = pd.DataFrame(stocks_info).T
stocks_info_df.columns=['tickers','security','gics_industry','gics_sub_industry']
stocks_info_df.set_index('tickers',inplace=True)

# Extract just the tickers list
tickers= stocks_info[0]

# %%
stocks_info_df['labels'] = stocks_info_df[['security', 'gics_industry','gics_sub_industry']].apply(lambda x: ' '.join(x), axis=1)

# %%
stocks_info_df
# Out:
#                                     security           gics_industry  \
# tickers
# mmm                               3M Company             industrials
# abt                      Abbott Laboratories             health care
# abbv                             AbbVie Inc.             health care
# acn                            Accenture plc  information technology
# atvi                     Activision Blizzard  information technology
# ayi                        Acuity Brands Inc             industrials
# adbe                       Adobe Systems Inc  information technology
# amd               Advanced Micro Devices Inc  information technology
# aap                       Advance Auto Parts  consumer discretionary
# aes                                 AES Corp               utilities
# aet                                Aetna Inc             health care
# amg            Affiliated Managers Group Inc              financials
# afl                                AFLAC Inc              financials
# a                   Agilent Technologies Inc             health care
# apd             Air Products & Chemicals Inc               materials
# akam                 Akamai Technologies Inc  information technology
# alk                     Alaska Air Group Inc             industrials
# alb                           Albemarle Corp               materials
# are      Alexandria Real Estate Equities Inc             real estate
# alxn                 Alexion Pharmaceuticals             health care
# algn                        Align Technology             health care
# alle                                Allegion             industrials
# agn                            Allergan, Plc             health care
# ads                    Alliance Data Systems  information technology
# lnt                      Alliant Energy Corp               utilities
# all                            Allstate Corp              financials
# googl                   Alphabet Inc Class A  information technology
# goog                    Alphabet Inc Class C  information technology
# mo                          Altria Group Inc        consumer staples
# amzn                          Amazon.com Inc  consumer discretionary
# ...                                      ...                     ...
# v                                  Visa Inc.  information technology
# vno                     Vornado Realty Trust             real estate
# vmc                         Vulcan Materials               materials
# wmt                          Wal-Mart Stores        consumer staples
# wba                 Walgreens Boots Alliance        consumer staples
# dis                  The Walt Disney Company  consumer discretionary
# wm                     Waste Management Inc.             industrials
# wat                       Waters Corporation             health care
# wec                     Wec Energy Group Inc               utilities
# wfc                              Wells Fargo              financials
# hcn                           Welltower Inc.             real estate
# wdc                          Western Digital  information technology
# wu                          Western Union Co  information technology
# wrk                         WestRock Company               materials
# wy                        Weyerhaeuser Corp.             real estate
# whr                          Whirlpool Corp.  consumer discretionary
# wfm                       Whole Foods Market        consumer staples
# wmb                            Williams Cos.                  energy
# wltw                    Willis Towers Watson              financials
# wyn                        Wyndham Worldwide  consumer discretionary
# wynn                        Wynn Resorts Ltd  consumer discretionary
# xel                          Xcel Energy Inc               utilities
# xrx                              Xerox Corp.  information technology
# xlnx                              Xilinx Inc  information technology
# xl                                XL Capital              financials
# xyl                               Xylem Inc.             industrials
# yum                          Yum! Brands Inc  consumer discretionary
# zbh                   Zimmer Biomet Holdings             health care
# zion                           Zions Bancorp              financials
# zts                                   Zoetis             health care
#
#                                     gics_sub_industry  \
# tickers
# mmm                          industrial conglomerates
# abt                             health care equipment
# abbv                                  pharmaceuticals
# acn                    it consulting & other services
# atvi                      home entertainment software
# ayi                 electrical components & equipment
# adbe                             application software
# amd                                    semiconductors
# aap                                 automotive retail
# aes      independent power producers & energy traders
# aet                               managed health care
# amg                  asset management & custody banks
# afl                           life & health insurance
# a                               health care equipment
# apd                                  industrial gases
# akam                     internet software & services
# alk                                          airlines
# alb                               specialty chemicals
# are                                      office reits
# alxn                                    biotechnology
# algn                             health care supplies
# alle                                building products
# agn                                   pharmaceuticals
# ads             data processing & outsourced services
# lnt                                electric utilities
# all                     property & casualty insurance
# googl                    internet software & services
# goog                     internet software & services
# mo                                            tobacco
# amzn               internet & direct marketing retail
# ...                                               ...
# v                        internet software & services
# vno                                      office reits
# vmc                            construction materials
# wmt                      hypermarkets & super centers
# wba                                       drug retail
# dis                                 cable & satellite
# wm                environmental & facilities services
# wat                          health care distributors
# wec                                electric utilities
# wfc                                 diversified banks
# hcn                                 health care reits
# wdc        technology hardware, storage & peripherals
# wu                       internet software & services
# wrk                                   paper packaging
# wy                                  specialized reits
# whr                              household appliances
# wfm                                       food retail
# wmb                oil & gas storage & transportation
# wltw                                insurance brokers
# wyn                    hotels, resorts & cruise lines
# wynn                                 casinos & gaming
# xel                                   multi-utilities
# xrx        technology hardware, storage & peripherals
# xlnx                                   semiconductors
# xl                      property & casualty insurance
# xyl                              industrial machinery
# yum                                       restaurants
# zbh                             health care equipment
# zion                                   regional banks
# zts                                   pharmaceuticals
#
#                                                     period  \
# tickers
# mmm        3M Company industrials industrial conglomerates
# abt      Abbott Laboratories health care health care eq...
# abbv               AbbVie Inc. health care pharmaceuticals
# acn      Accenture plc information technology it consul...
# atvi     Activision Blizzard information technology hom...
# ayi      Acuity Brands Inc industrials electrical compo...
# adbe     Adobe Systems Inc information technology appli...
# amd      Advanced Micro Devices Inc information technol...
# aap      Advance Auto Parts consumer discretionary auto...
# aes      AES Corp utilities independent power producers...
# aet              Aetna Inc health care managed health care
# amg      Affiliated Managers Group Inc financials asset...
# afl           AFLAC Inc financials life & health insurance
# a        Agilent Technologies Inc health care health ca...
# apd      Air Products & Chemicals Inc materials industr...
# akam     Akamai Technologies Inc information technology...
# alk              Alaska Air Group Inc industrials airlines
# alb           Albemarle Corp materials specialty chemicals
# are      Alexandria Real Estate Equities Inc real estat...
# alxn     Alexion Pharmaceuticals health care biotechnology
# algn     Align Technology health care health care supplies
# alle                Allegion industrials building products
# agn              Allergan, Plc health care pharmaceuticals
# ads      Alliance Data Systems information technology d...
# lnt       Alliant Energy Corp utilities electric utilities
# all      Allstate Corp financials property & casualty i...
# googl    Alphabet Inc Class A information technology in...
# goog     Alphabet Inc Class C information technology in...
# mo               Altria Group Inc consumer staples tobacco
# amzn     Amazon.com Inc consumer discretionary internet...
# ...                                                    ...
# v        Visa Inc. information technology internet soft...
# vno          Vornado Realty Trust real estate office reits
# vmc      Vulcan Materials materials construction materials
# wmt      Wal-Mart Stores consumer staples hypermarkets ...
# wba      Walgreens Boots Alliance consumer staples drug...
# dis      The Walt Disney Company consumer discretionary...
# wm       Waste Management Inc. industrials environmenta...
# wat      Waters Corporation health care health care dis...
# wec      Wec Energy Group Inc utilities electric utilities
# wfc               Wells Fargo financials diversified banks
# hcn           Welltower Inc. real estate health care reits
# wdc      Western Digital information technology technol...
# wu       Western Union Co information technology intern...
# wrk             WestRock Company materials paper packaging
# wy        Weyerhaeuser Corp. real estate specialized reits
# whr      Whirlpool Corp. consumer discretionary househo...
# wfm        Whole Foods Market consumer staples food retail
# wmb      Williams Cos. energy oil & gas storage & trans...
# wltw     Willis Towers Watson financials insurance brokers
# wyn      Wyndham Worldwide consumer discretionary hotel...
# wynn     Wynn Resorts Ltd consumer discretionary casino...
# xel              Xcel Energy Inc utilities multi-utilities
# xrx      Xerox Corp. information technology technology ...
# xlnx      Xilinx Inc information technology semiconductors
# xl       XL Capital financials property & casualty insu...
# xyl            Xylem Inc. industrials industrial machinery
# yum      Yum! Brands Inc consumer discretionary restaur...
# zbh      Zimmer Biomet Holdings health care health care...
# zion               Zions Bancorp financials regional banks
# zts                     Zoetis health care pharmaceuticals
#
#                                                     labels
# tickers
# mmm        3M Company industrials industrial conglomerates
# abt      Abbott Laboratories health care health care eq...
# abbv               AbbVie Inc. health care pharmaceuticals
# acn      Accenture plc information technology it consul...
# atvi     Activision Blizzard information technology hom...
# ayi      Acuity Brands Inc industrials electrical compo...
# adbe     Adobe Systems Inc information technology appli...
# amd      Advanced Micro Devices Inc information technol...
# aap      Advance Auto Parts consumer discretionary auto...
# aes      AES Corp utilities independent power producers...
# aet              Aetna Inc health care managed health care
# amg      Affiliated Managers Group Inc financials asset...
# afl           AFLAC Inc financials life & health insurance
# a        Agilent Technologies Inc health care health ca...
# apd      Air Products & Chemicals Inc materials industr...
# akam     Akamai Technologies Inc information technology...
# alk              Alaska Air Group Inc industrials airlines
# alb           Albemarle Corp materials specialty chemicals
# are      Alexandria Real Estate Equities Inc real estat...
# alxn     Alexion Pharmaceuticals health care biotechnology
# algn     Align Technology health care health care supplies
# alle                Allegion industrials building products
# agn              Allergan, Plc health care pharmaceuticals
# ads      Alliance Data Systems information technology d...
# lnt       Alliant Energy Corp utilities electric utilities
# all      Allstate Corp financials property & casualty i...
# googl    Alphabet Inc Class A information technology in...
# goog     Alphabet Inc Class C information technology in...
# mo               Altria Group Inc consumer staples tobacco
# amzn     Amazon.com Inc consumer discretionary internet...
# ...                                                    ...
# v        Visa Inc. information technology internet soft...
# vno          Vornado Realty Trust real estate office reits
# vmc      Vulcan Materials materials construction materials
# wmt      Wal-Mart Stores consumer staples hypermarkets ...
# wba      Walgreens Boots Alliance consumer staples drug...
# dis      The Walt Disney Company consumer discretionary...
# wm       Waste Management Inc. industrials environmenta...
# wat      Waters Corporation health care health care dis...
# wec      Wec Energy Group Inc utilities electric utilities
# wfc               Wells Fargo financials diversified banks
# hcn           Welltower Inc. real estate health care reits
# wdc      Western Digital information technology technol...
# wu       Western Union Co information technology intern...
# wrk             WestRock Company materials paper packaging
# wy        Weyerhaeuser Corp. real estate specialized reits
# whr      Whirlpool Corp. consumer discretionary househo...
# wfm        Whole Foods Market consumer staples food retail
# wmb      Williams Cos. energy oil & gas storage & trans...
# wltw     Willis Towers Watson financials insurance brokers
# wyn      Wyndham Worldwide consumer discretionary hotel...
# wynn     Wynn Resorts Ltd consumer discretionary casino...
# xel              Xcel Energy Inc utilities multi-utilities
# xrx      Xerox Corp. information technology technology ...
# xlnx      Xilinx Inc information technology semiconductors
# xl       XL Capital financials property & casualty insu...
# xyl            Xylem Inc. industrials industrial machinery
# yum      Yum! Brands Inc consumer discretionary restaur...
# zbh      Zimmer Biomet Holdings health care health care...
# zion               Zions Bancorp financials regional banks
# zts                     Zoetis health care pharmaceuticals
#
# [505 rows x 5 columns]

# %%
# Create a list of dict based on tickers and labels
dictlist = []
for index, row in stocks_info_df.iterrows():
    dictlist.append({'value':index, 'label':row['labels']})

# %%
dictlist
# Out:
# [{'labels': u'3M Company industrials industrial conglomerates',
#   'values': u'mmm'},
#  {'labels': u'Abbott Laboratories health care health care equipment',
#   'values': u'abt'},
#  {'labels': u'AbbVie Inc. health care pharmaceuticals', 'values': u'abbv'},
#  {'labels': u'Accenture plc information technology it consulting & other services',
#   'values': u'acn'},
#  {'labels': u'Activision Blizzard information technology home entertainment software',
#   'values': u'atvi'},
#  {'labels': u'Acuity Brands Inc industrials electrical components & equipment',
#   'values': u'ayi'},
#  {'labels': u'Adobe Systems Inc information technology application software',
#   'values': u'adbe'},
#  {'labels': u'Advanced Micro Devices Inc information technology semiconductors',
#   'values': u'amd'},
#  {'labels': u'Advance Auto Parts consumer discretionary automotive retail',
#   'values': u'aap'},
#  {'labels': u'AES Corp utilities independent power producers & energy traders',
#   'values': u'aes'},
#  {'labels': u'Aetna Inc health care managed health care', 'values': u'aet'},
#  {'labels': u'Affiliated Managers Group Inc financials asset management & custody banks',
#   'values': u'amg'},
#  {'labels': u'AFLAC Inc financials life & health insurance', 'values': u'afl'},
#  {'labels': u'Agilent Technologies Inc health care health care equipment',
#   'values': u'a'},
#  {'labels': u'Air Products & Chemicals Inc materials industrial gases',
#   'values': u'apd'},
#  {'labels': u'Akamai Technologies Inc information technology internet software & services',
#   'values': u'akam'},
#  {'labels': u'Alaska Air Group Inc industrials airlines', 'values': u'alk'},
#  {'labels': u'Albemarle Corp materials specialty chemicals', 'values': u'alb'},
#  {'labels': u'Alexandria Real Estate Equities Inc real estate office reits',
#   'values': u'are'},
#  {'labels': u'Alexion Pharmaceuticals health care biotechnology',
#   'values': u'alxn'},
#  {'labels': u'Align Technology health care health care supplies',
#   'values': u'algn'},
#  {'labels': u'Allegion industrials building products', 'values': u'alle'},
#  {'labels': u'Allergan, Plc health care pharmaceuticals', 'values': u'agn'},
#  {'labels': u'Alliance Data Systems information technology data processing & outsourced services',
#   'values': u'ads'},
#  {'labels': u'Alliant Energy Corp utilities electric utilities',
#   'values': u'lnt'},
#  {'labels': u'Allstate Corp financials property & casualty insurance',
#   'values': u'all'},
#  {'labels': u'Alphabet Inc Class A information technology internet software & services',
#   'values': u'googl'},
#  {'labels': u'Alphabet Inc Class C information technology internet software & services',
#   'values': u'goog'},
#  {'labels': u'Altria Group Inc consumer staples tobacco', 'values': u'mo'},
#  {'labels': u'Amazon.com Inc consumer discretionary internet & direct marketing retail',
#   'values': u'amzn'},
#  {'labels': u'Ameren Corp utilities multi-utilities', 'values': u'aee'},
#  {'labels': u'American Airlines Group industrials airlines', 'values': u'aal'},
#  {'labels': u'American Electric Power utilities electric utilities',
#   'values': u'aep'},
#  {'labels': u'American Express Co financials consumer finance',
#   'values': u'axp'},
#  {'labels': u'American International Group, Inc. financials property & casualty insurance',
#   'values': u'aig'},
#  {'labels': u'American Tower Corp A real estate specialized reits',
#   'values': u'amt'},
#  {'labels': u'American Water Works Company Inc utilities water utilities',
#   'values': u'awk'},
#  {'labels': u'Ameriprise Financial financials asset management & custody banks',
#   'values': u'amp'},
#  {'labels': u'AmerisourceBergen Corp health care health care distributors',
#   'values': u'abc'},
#  {'labels': u'AMETEK Inc industrials electrical components & equipment',
#   'values': u'ame'},
#  {'labels': u'Amgen Inc health care biotechnology', 'values': u'amgn'},
#  {'labels': u'Amphenol Corp information technology electronic components',
#   'values': u'aph'},
#  {'labels': u'Anadarko Petroleum Corp energy oil & gas exploration & production',
#   'values': u'apc'},
#  {'labels': u'Analog Devices, Inc. information technology semiconductors',
#   'values': u'adi'},
#  {'labels': u'ANSYS Inc information technology application software',
#   'values': u'anss'},
#  {'labels': u'Anthem Inc. health care managed health care', 'values': u'antm'},
#  {'labels': u'Aon plc financials insurance brokers', 'values': u'aon'},
#  {'labels': u'Apache Corporation energy oil & gas exploration & production',
#   'values': u'apa'},
#  {'labels': u'Apartment Investment & Management real estate residential reits',
#   'values': u'aiv'},
#  {'labels': u'Apple Inc. information technology technology hardware, storage & peripherals',
#   'values': u'aapl'},
#  {'labels': u'Applied Materials Inc information technology semiconductor equipment',
#   'values': u'amat'},
#  {'labels': u'Archer-Daniels-Midland Co consumer staples agricultural products',
#   'values': u'adm'},
#  {'labels': u'Arconic Inc industrials aerospace & defense', 'values': u'arnc'},
#  {'labels': u'Arthur J. Gallagher & Co. financials insurance brokers',
#   'values': u'ajg'},
#  {'labels': u'Assurant Inc financials multi-line insurance', 'values': u'aiz'},
#  {'labels': u'AT&T Inc telecommunication services integrated telecommunication services',
#   'values': u't'},
#  {'labels': u'Autodesk Inc information technology application software',
#   'values': u'adsk'},
#  {'labels': u'Automatic Data Processing information technology internet software & services',
#   'values': u'adp'},
#  {'labels': u'AutoNation Inc consumer discretionary specialty stores',
#   'values': u'an'},
#  {'labels': u'AutoZone Inc consumer discretionary specialty stores',
#   'values': u'azo'},
#  {'labels': u'AvalonBay Communities, Inc. real estate residential reits',
#   'values': u'avb'},
#  {'labels': u'Avery Dennison Corp materials paper packaging',
#   'values': u'avy'},
#  {'labels': u'Baker Hughes Inc energy oil & gas equipment & services',
#   'values': u'bhi'},
#  {'labels': u'Ball Corp materials metal & glass containers', 'values': u'bll'},
#  {'labels': u'Bank of America Corp financials diversified banks',
#   'values': u'bac'},
#  {'labels': u'The Bank of New York Mellon Corp. financials asset management & custody banks',
#   'values': u'bk'},
#  {'labels': u'Bard (C.R.) Inc. health care health care equipment',
#   'values': u'bcr'},
#  {'labels': u'Baxter International Inc. health care health care equipment',
#   'values': u'bax'},
#  {'labels': u'BB&T Corporation financials regional banks', 'values': u'bbt'},
#  {'labels': u'Becton Dickinson health care health care equipment',
#   'values': u'bdx'},
#  {'labels': u'Bed Bath & Beyond consumer discretionary specialty stores',
#   'values': u'bbby'},
#  {'labels': u'Berkshire Hathaway financials multi-sector holdings',
#   'values': u'brk.b'},
#  {'labels': u'Best Buy Co. Inc. consumer discretionary computer & electronics retail',
#   'values': u'bby'},
#  {'labels': u'Biogen Inc. health care biotechnology', 'values': u'biib'},
#  {'labels': u'BlackRock financials asset management & custody banks',
#   'values': u'blk'},
#  {'labels': u'Block H&R financials consumer finance', 'values': u'hrb'},
#  {'labels': u'Boeing Company industrials aerospace & defense',
#   'values': u'ba'},
#  {'labels': u'BorgWarner consumer discretionary auto parts & equipment',
#   'values': u'bwa'},
#  {'labels': u'Boston Properties real estate office reits', 'values': u'bxp'},
#  {'labels': u'Boston Scientific health care health care equipment',
#   'values': u'bsx'},
#  {'labels': u'Bristol-Myers Squibb health care health care distributors',
#   'values': u'bmy'},
#  {'labels': u'Broadcom information technology semiconductors',
#   'values': u'avgo'},
#  {'labels': u'Brown-Forman Corp. consumer staples distillers & vintners',
#   'values': u'bf.b'},
#  {'labels': u'C. H. Robinson Worldwide industrials air freight & logistics',
#   'values': u'chrw'},
#  {'labels': u'CA, Inc. information technology systems software',
#   'values': u'ca'},
#  {'labels': u'Cabot Oil & Gas energy oil & gas exploration & production',
#   'values': u'cog'},
#  {'labels': u'Campbell Soup consumer staples packaged foods & meats',
#   'values': u'cpb'},
#  {'labels': u'Capital One Financial financials consumer finance',
#   'values': u'cof'},
#  {'labels': u'Cardinal Health Inc. health care health care distributors',
#   'values': u'cah'},
#  {'labels': u'CBOE Holdings financials financial exchanges & data',
#   'values': u'cboe'},
#  {'labels': u'Carmax Inc consumer discretionary specialty stores',
#   'values': u'kmx'},
#  {'labels': u'Carnival Corp. consumer discretionary hotels, resorts & cruise lines',
#   'values': u'ccl'},
#  {'labels': u'Caterpillar Inc. industrials construction machinery & heavy trucks',
#   'values': u'cat'},
#  {'labels': u'CBRE Group real estate real estate services', 'values': u'cbg'},
#  {'labels': u'CBS Corp. consumer discretionary broadcasting',
#   'values': u'cbs'},
#  {'labels': u'Celgene Corp. health care biotechnology', 'values': u'celg'},
#  {'labels': u'Centene Corporation health care managed health care',
#   'values': u'cnc'},
#  {'labels': u'CenterPoint Energy utilities multi-utilities', 'values': u'cnp'},
#  {'labels': u'CenturyLink Inc telecommunication services integrated telecommunication services',
#   'values': u'ctl'},
#  {'labels': u'Cerner health care health care technology', 'values': u'cern'},
#  {'labels': u'CF Industries Holdings Inc materials fertilizers & agricultural chemicals',
#   'values': u'cf'},
#  {'labels': u'Charles Schwab Corporation financials investment banking & brokerage',
#   'values': u'schw'},
#  {'labels': u'Charter Communications consumer discretionary cable & satellite',
#   'values': u'chtr'},
#  {'labels': u'Chesapeake Energy energy oil & gas exploration & production',
#   'values': u'chk'},
#  {'labels': u'Chevron Corp. energy integrated oil & gas', 'values': u'cvx'},
#  {'labels': u'Chipotle Mexican Grill consumer discretionary restaurants',
#   'values': u'cmg'},
#  {'labels': u'Chubb Limited financials property & casualty insurance',
#   'values': u'cb'},
#  {'labels': u'Church & Dwight consumer staples household products',
#   'values': u'chd'},
#  {'labels': u'CIGNA Corp. health care managed health care', 'values': u'ci'},
#  {'labels': u'Cimarex Energy energy oil & gas exploration & production',
#   'values': u'xec'},
#  {'labels': u'Cincinnati Financial financials property & casualty insurance',
#   'values': u'cinf'},
#  {'labels': u'Cintas Corporation industrials diversified support services',
#   'values': u'ctas'},
#  {'labels': u'Cisco Systems information technology communications equipment',
#   'values': u'csco'},
#  {'labels': u'Citigroup Inc. financials diversified banks', 'values': u'c'},
#  {'labels': u'Citizens Financial Group financials regional banks',
#   'values': u'cfg'},
#  {'labels': u'Citrix Systems information technology internet software & services',
#   'values': u'ctxs'},
#  {'labels': u'The Clorox Company consumer staples household products',
#   'values': u'clx'},
#  {'labels': u'CME Group Inc. financials financial exchanges & data',
#   'values': u'cme'},
#  {'labels': u'CMS Energy utilities multi-utilities', 'values': u'cms'},
#  {'labels': u'Coach Inc. consumer discretionary apparel, accessories & luxury goods',
#   'values': u'coh'},
#  {'labels': u'Coca-Cola Company (The) consumer staples soft drinks',
#   'values': u'ko'},
#  {'labels': u'Cognizant Technology Solutions information technology it consulting & other services',
#   'values': u'ctsh'},
#  {'labels': u'Colgate-Palmolive consumer staples household products',
#   'values': u'cl'},
#  {'labels': u'Comcast Corp. consumer discretionary cable & satellite',
#   'values': u'cmcsa'},
#  {'labels': u'Comerica Inc. financials diversified banks', 'values': u'cma'},
#  {'labels': u'Conagra Brands consumer staples packaged foods & meats',
#   'values': u'cag'},
#  {'labels': u'Concho Resources energy oil & gas exploration & production',
#   'values': u'cxo'},
#  {'labels': u'ConocoPhillips energy oil & gas exploration & production',
#   'values': u'cop'},
#  {'labels': u'Consolidated Edison utilities electric utilities',
#   'values': u'ed'},
#  {'labels': u'Constellation Brands consumer staples distillers & vintners',
#   'values': u'stz'},
#  {'labels': u'The Cooper Companies health care health care supplies',
#   'values': u'coo'},
#  {'labels': u'Corning Inc. information technology electronic components',
#   'values': u'glw'},
#  {'labels': u'Costco Wholesale Corp. consumer staples hypermarkets & super centers',
#   'values': u'cost'},
#  {'labels': u'Coty, Inc consumer staples personal products',
#   'values': u'coty'},
#  {'labels': u'Crown Castle International Corp. real estate specialized reits',
#   'values': u'cci'},
#  {'labels': u'CSRA Inc. information technology it consulting & other services',
#   'values': u'csra'},
#  {'labels': u'CSX Corp. industrials railroads', 'values': u'csx'},
#  {'labels': u'Cummins Inc. industrials industrial machinery',
#   'values': u'cmi'},
#  {'labels': u'CVS Health consumer staples drug retail', 'values': u'cvs'},
#  {'labels': u'D. R. Horton consumer discretionary homebuilding',
#   'values': u'dhi'},
#  {'labels': u'Danaher Corp. health care health care equipment',
#   'values': u'dhr'},
#  {'labels': u'Darden Restaurants consumer discretionary restaurants',
#   'values': u'dri'},
#  {'labels': u'DaVita Inc. health care health care facilities',
#   'values': u'dva'},
#  {'labels': u'Deere & Co. industrials agricultural & farm machinery',
#   'values': u'de'},
#  {'labels': u'Delphi Automotive PLC consumer discretionary auto parts & equipment',
#   'values': u'dlph'},
#  {'labels': u'Delta Air Lines Inc. industrials airlines', 'values': u'dal'},
#  {'labels': u'Dentsply Sirona health care health care supplies',
#   'values': u'xray'},
#  {'labels': u'Devon Energy Corp. energy oil & gas exploration & production',
#   'values': u'dvn'},
#  {'labels': u'Digital Realty Trust Inc real estate specialized reits',
#   'values': u'dlr'},
#  {'labels': u'Discover Financial Services financials consumer finance',
#   'values': u'dfs'},
#  {'labels': u'Discovery Communications-A consumer discretionary cable & satellite',
#   'values': u'disca'},
#  {'labels': u'Discovery Communications-C consumer discretionary cable & satellite',
#   'values': u'disck'},
#  {'labels': u'Dish Network consumer discretionary cable & satellite',
#   'values': u'dish'},
#  {'labels': u'Dollar General consumer discretionary general merchandise stores',
#   'values': u'dg'},
#  {'labels': u'Dollar Tree consumer discretionary general merchandise stores',
#   'values': u'dltr'},
#  {'labels': u'Dominion Resources utilities electric utilities',
#   'values': u'd'},
#  {'labels': u'Dover Corp. industrials industrial machinery', 'values': u'dov'},
#  {'labels': u'Dow Chemical materials diversified chemicals', 'values': u'dow'},
#  {'labels': u'Dr Pepper Snapple Group consumer staples soft drinks',
#   'values': u'dps'},
#  {'labels': u'DTE Energy Co. utilities multi-utilities', 'values': u'dte'},
#  {'labels': u'Du Pont (E.I.) materials diversified chemicals',
#   'values': u'dd'},
#  {'labels': u'Duke Energy utilities electric utilities', 'values': u'duk'},
#  {'labels': u'DXC Technology information technology it consulting & other services',
#   'values': u'dxc'},
#  {'labels': u'E*Trade financials investment banking & brokerage',
#   'values': u'etfc'},
#  {'labels': u'Eastman Chemical materials diversified chemicals',
#   'values': u'emn'},
#  {'labels': u'Eaton Corporation industrials electrical components & equipment',
#   'values': u'etn'},
#  {'labels': u'eBay Inc. information technology internet software & services',
#   'values': u'ebay'},
#  {'labels': u'Ecolab Inc. materials specialty chemicals', 'values': u'ecl'},
#  {'labels': u"Edison Int'l utilities electric utilities", 'values': u'eix'},
#  {'labels': u'Edwards Lifesciences health care health care equipment',
#   'values': u'ew'},
#  {'labels': u'Electronic Arts information technology home entertainment software',
#   'values': u'ea'},
#  {'labels': u'Emerson Electric Company industrials electrical components & equipment',
#   'values': u'emr'},
#  {'labels': u'Entergy Corp. utilities electric utilities', 'values': u'etr'},
#  {'labels': u'Envision Healthcare health care health care services',
#   'values': u'evhc'},
#  {'labels': u'EOG Resources energy oil & gas exploration & production',
#   'values': u'eog'},
#  {'labels': u'EQT Corporation energy oil & gas exploration & production',
#   'values': u'eqt'},
#  {'labels': u'Equifax Inc. industrials research & consulting services',
#   'values': u'efx'},
#  {'labels': u'Equinix real estate specialized reits', 'values': u'eqix'},
#  {'labels': u'Equity Residential real estate residential reits',
#   'values': u'eqr'},
#  {'labels': u'Essex Property Trust, Inc. real estate residential reits',
#   'values': u'ess'},
#  {'labels': u'Estee Lauder Cos. consumer staples personal products',
#   'values': u'el'},
#  {'labels': u'Eversource Energy utilities multi-utilities', 'values': u'es'},
#  {'labels': u'Everest Re Group Ltd financials reinsurance', 'values': u're'},
#  {'labels': u'Exelon Corp. utilities multi-utilities', 'values': u'exc'},
#  {'labels': u'Expedia Inc. consumer discretionary internet & direct marketing retail',
#   'values': u'expe'},
#  {'labels': u'Expeditors International industrials air freight & logistics',
#   'values': u'expd'},
#  {'labels': u'Express Scripts health care health care distributors',
#   'values': u'esrx'},
#  {'labels': u'Extra Space Storage real estate specialized reits',
#   'values': u'exr'},
#  {'labels': u'Exxon Mobil Corp. energy integrated oil & gas',
#   'values': u'xom'},
#  {'labels': u'F5 Networks information technology communications equipment',
#   'values': u'ffiv'},
#  {'labels': u'Facebook, Inc. information technology internet software & services',
#   'values': u'fb'},
#  {'labels': u'Fastenal Co industrials building products', 'values': u'fast'},
#  {'labels': u'Federal Realty Investment Trust real estate retail reits',
#   'values': u'frt'},
#  {'labels': u'FedEx Corporation industrials air freight & logistics',
#   'values': u'fdx'},
#  {'labels': u'Fidelity National Information Services information technology internet software & services',
#   'values': u'fis'},
#  {'labels': u'Fifth Third Bancorp financials regional banks',
#   'values': u'fitb'},
#  {'labels': u'FirstEnergy Corp utilities electric utilities', 'values': u'fe'},
#  {'labels': u'Fiserv Inc information technology internet software & services',
#   'values': u'fisv'},
#  {'labels': u'FLIR Systems information technology electronic equipment & instruments',
#   'values': u'flir'},
#  {'labels': u'Flowserve Corporation industrials industrial machinery',
#   'values': u'fls'},
#  {'labels': u'Fluor Corp. industrials construction & engineering',
#   'values': u'flr'},
#  {'labels': u'FMC Corporation materials fertilizers & agricultural chemicals',
#   'values': u'fmc'},
#  {'labels': u'Foot Locker Inc consumer discretionary apparel retail',
#   'values': u'fl'},
#  {'labels': u'Ford Motor consumer discretionary automobile manufacturers',
#   'values': u'f'},
#  {'labels': u'Fortive Corp industrials industrial machinery',
#   'values': u'ftv'},
#  {'labels': u'Fortune Brands Home & Security industrials building products',
#   'values': u'fbhs'},
#  {'labels': u'Franklin Resources financials asset management & custody banks',
#   'values': u'ben'},
#  {'labels': u'Freeport-McMoRan Inc. materials copper', 'values': u'fcx'},
#  {'labels': u'Gap Inc. consumer discretionary apparel retail',
#   'values': u'gps'},
#  {'labels': u'Garmin Ltd. consumer discretionary consumer electronics',
#   'values': u'grmn'},
#  {'labels': u'Gartner Inc information technology it consulting & other services',
#   'values': u'it'},
#  {'labels': u'General Dynamics industrials aerospace & defense',
#   'values': u'gd'},
#  {'labels': u'General Electric industrials industrial conglomerates',
#   'values': u'ge'},
#  {'labels': u'General Growth Properties Inc. real estate retail reits',
#   'values': u'ggp'},
#  {'labels': u'General Mills consumer staples packaged foods & meats',
#   'values': u'gis'},
#  {'labels': u'General Motors consumer discretionary automobile manufacturers',
#   'values': u'gm'},
#  {'labels': u'Genuine Parts consumer discretionary specialty stores',
#   'values': u'gpc'},
#  {'labels': u'Gilead Sciences health care biotechnology', 'values': u'gild'},
#  {'labels': u'Global Payments Inc information technology data processing & outsourced services',
#   'values': u'gpn'},
#  {'labels': u'Goldman Sachs Group financials investment banking & brokerage',
#   'values': u'gs'},
#  {'labels': u'Goodyear Tire & Rubber consumer discretionary tires & rubber',
#   'values': u'gt'},
#  {'labels': u'Grainger (W.W.) Inc. industrials industrial machinery',
#   'values': u'gww'},
#  {'labels': u'Halliburton Co. energy oil & gas equipment & services',
#   'values': u'hal'},
#  {'labels': u'Hanesbrands Inc consumer discretionary apparel, accessories & luxury goods',
#   'values': u'hbi'},
#  {'labels': u'Harley-Davidson consumer discretionary motorcycle manufacturers',
#   'values': u'hog'},
#  {'labels': u'Harris Corporation information technology communications equipment',
#   'values': u'hrs'},
#  {'labels': u'Hartford Financial Svc.Gp. financials property & casualty insurance',
#   'values': u'hig'},
#  {'labels': u'Hasbro Inc. consumer discretionary leisure products',
#   'values': u'has'},
#  {'labels': u'HCA Holdings health care health care facilities',
#   'values': u'hca'},
#  {'labels': u'HCP Inc. real estate health care reits', 'values': u'hcp'},
#  {'labels': u'Helmerich & Payne energy oil & gas drilling', 'values': u'hp'},
#  {'labels': u'Henry Schein health care health care distributors',
#   'values': u'hsic'},
#  {'labels': u'The Hershey Company consumer staples packaged foods & meats',
#   'values': u'hsy'},
#  {'labels': u'Hess Corporation energy integrated oil & gas', 'values': u'hes'},
#  {'labels': u'Hewlett Packard Enterprise information technology technology hardware, storage & peripherals',
#   'values': u'hpe'},
#  {'labels': u'Hilton Worldwide Holdings Inc consumer discretionary hotels, resorts & cruise lines',
#   'values': u'hlt'},
#  {'labels': u'Hologic health care health care equipment', 'values': u'holx'},
#  {'labels': u'Home Depot consumer discretionary home improvement retail',
#   'values': u'hd'},
#  {'labels': u"Honeywell Int'l Inc. industrials industrial conglomerates",
#   'values': u'hon'},
#  {'labels': u'Hormel Foods Corp. consumer staples packaged foods & meats',
#   'values': u'hrl'},
#  {'labels': u'Host Hotels & Resorts real estate hotel & resort reits',
#   'values': u'hst'},
#  {'labels': u'HP Inc. information technology technology hardware, storage & peripherals',
#   'values': u'hpq'},
#  {'labels': u'Humana Inc. health care managed health care', 'values': u'hum'},
#  {'labels': u'Huntington Bancshares financials regional banks',
#   'values': u'hban'},
#  {'labels': u'IDEXX Laboratories health care health care equipment',
#   'values': u'idxx'},
#  {'labels': u'IHS Markit Ltd. industrials research & consulting services',
#   'values': u'info'},
#  {'labels': u'Illinois Tool Works industrials industrial machinery',
#   'values': u'itw'},
#  {'labels': u'Illumina Inc health care life sciences tools & services',
#   'values': u'ilmn'},
#  {'labels': u'Ingersoll-Rand PLC industrials industrial machinery',
#   'values': u'ir'},
#  {'labels': u'Intel Corp. information technology semiconductors',
#   'values': u'intc'},
#  {'labels': u'Intercontinental Exchange financials financial exchanges & data',
#   'values': u'ice'},
#  {'labels': u'International Business Machines information technology it consulting & other services',
#   'values': u'ibm'},
#  {'labels': u'Incyte health care biotechnology', 'values': u'incy'},
#  {'labels': u'International Paper materials paper packaging', 'values': u'ip'},
#  {'labels': u'Interpublic Group consumer discretionary advertising',
#   'values': u'ipg'},
#  {'labels': u'Intl Flavors & Fragrances materials specialty chemicals',
#   'values': u'iff'},
#  {'labels': u'Intuit Inc. information technology internet software & services',
#   'values': u'intu'},
#  {'labels': u'Intuitive Surgical Inc. health care health care equipment',
#   'values': u'isrg'},
#  {'labels': u'Invesco Ltd. financials asset management & custody banks',
#   'values': u'ivz'},
#  {'labels': u'Iron Mountain Incorporated real estate specialized reits',
#   'values': u'irm'},
#  {'labels': u'Jacobs Engineering Group industrials construction & engineering',
#   'values': u'jec'},
#  {'labels': u'J. B. Hunt Transport Services industrials trucking',
#   'values': u'jbht'},
#  {'labels': u'JM Smucker consumer staples packaged foods & meats',
#   'values': u'sjm'},
#  {'labels': u'Johnson & Johnson health care health care equipment',
#   'values': u'jnj'},
#  {'labels': u'Johnson Controls International industrials building products',
#   'values': u'jci'},
#  {'labels': u'JPMorgan Chase & Co. financials diversified banks',
#   'values': u'jpm'},
#  {'labels': u'Juniper Networks information technology communications equipment',
#   'values': u'jnpr'},
#  {'labels': u'Kansas City Southern industrials railroads', 'values': u'ksu'},
#  {'labels': u'Kellogg Co. consumer staples packaged foods & meats',
#   'values': u'k'},
#  {'labels': u'KeyCorp financials regional banks', 'values': u'key'},
#  {'labels': u'Kimberly-Clark consumer staples household products',
#   'values': u'kmb'},
#  {'labels': u'Kimco Realty real estate retail reits', 'values': u'kim'},
#  {'labels': u'Kinder Morgan energy oil & gas storage & transportation',
#   'values': u'kmi'},
#  {'labels': u'KLA-Tencor Corp. information technology semiconductor equipment',
#   'values': u'klac'},
#  {'labels': u"Kohl's Corp. consumer discretionary general merchandise stores",
#   'values': u'kss'},
#  {'labels': u'Kraft Heinz Co consumer staples packaged foods & meats',
#   'values': u'khc'},
#  {'labels': u'Kroger Co. consumer staples food retail', 'values': u'kr'},
#  {'labels': u'L Brands Inc. consumer discretionary apparel retail',
#   'values': u'lb'},
#  {'labels': u'L-3 Communications Holdings industrials aerospace & defense',
#   'values': u'lll'},
#  {'labels': u'Laboratory Corp. of America Holding health care health care services',
#   'values': u'lh'},
#  {'labels': u'Lam Research information technology semiconductor equipment',
#   'values': u'lrcx'},
#  {'labels': u'Leggett & Platt consumer discretionary home furnishings',
#   'values': u'leg'},
#  {'labels': u'Lennar Corp. consumer discretionary homebuilding',
#   'values': u'len'},
#  {'labels': u'Level 3 Communications telecommunication services alternative carriers',
#   'values': u'lvlt'},
#  {'labels': u'Leucadia National Corp. financials multi-sector holdings',
#   'values': u'luk'},
#  {'labels': u'Lilly (Eli) & Co. health care pharmaceuticals',
#   'values': u'lly'},
#  {'labels': u'Lincoln National financials multi-line insurance',
#   'values': u'lnc'},
#  {'labels': u'LKQ Corporation consumer discretionary distributors',
#   'values': u'lkq'},
#  {'labels': u'Lockheed Martin Corp. industrials aerospace & defense',
#   'values': u'lmt'},
#  {'labels': u'Loews Corp. financials multi-line insurance', 'values': u'l'},
#  {'labels': u"Lowe's Cos. consumer discretionary home improvement retail",
#   'values': u'low'},
#  {'labels': u'LyondellBasell materials specialty chemicals', 'values': u'lyb'},
#  {'labels': u'M&T Bank Corp. financials regional banks', 'values': u'mtb'},
#  {'labels': u'Macerich real estate retail reits', 'values': u'mac'},
#  {'labels': u"Macy's Inc. consumer discretionary department stores",
#   'values': u'm'},
#  {'labels': u'Mallinckrodt Plc health care pharmaceuticals', 'values': u'mnk'},
#  {'labels': u'Marathon Oil Corp. energy oil & gas exploration & production',
#   'values': u'mro'},
#  {'labels': u'Marathon Petroleum energy oil & gas refining & marketing',
#   'values': u'mpc'},
#  {'labels': u"Marriott Int'l. consumer discretionary hotels, resorts & cruise lines",
#   'values': u'mar'},
#  {'labels': u'Marsh & McLennan financials insurance brokers',
#   'values': u'mmc'},
#  {'labels': u'Martin Marietta Materials materials construction materials',
#   'values': u'mlm'},
#  {'labels': u'Masco Corp. industrials building products', 'values': u'mas'},
#  {'labels': u'Mastercard Inc. information technology internet software & services',
#   'values': u'ma'},
#  {'labels': u'Mattel Inc. consumer discretionary leisure products',
#   'values': u'mat'},
#  {'labels': u'McCormick & Co. consumer staples packaged foods & meats',
#   'values': u'mkc'},
#  {'labels': u"McDonald's Corp. consumer discretionary restaurants",
#   'values': u'mcd'},
#  {'labels': u'McKesson Corp. health care health care distributors',
#   'values': u'mck'},
#  {'labels': u'Medtronic plc health care health care equipment',
#   'values': u'mdt'},
#  {'labels': u'Merck & Co. health care pharmaceuticals', 'values': u'mrk'},
#  {'labels': u'MetLife Inc. financials life & health insurance',
#   'values': u'met'},
#  {'labels': u'Mettler Toledo health care life sciences tools & services',
#   'values': u'mtd'},
#  {'labels': u'Michael Kors Holdings consumer discretionary apparel, accessories & luxury goods',
#   'values': u'kors'},
#  {'labels': u'Microchip Technology information technology semiconductors',
#   'values': u'mchp'},
#  {'labels': u'Micron Technology information technology semiconductors',
#   'values': u'mu'},
#  {'labels': u'Microsoft Corp. information technology systems software',
#   'values': u'msft'},
#  {'labels': u'Mid-America Apartments real estate residential reits',
#   'values': u'maa'},
#  {'labels': u'Mohawk Industries consumer discretionary home furnishings',
#   'values': u'mhk'},
#  {'labels': u'Molson Coors Brewing Company consumer staples brewers',
#   'values': u'tap'},
#  {'labels': u'Mondelez International consumer staples packaged foods & meats',
#   'values': u'mdlz'},
#  {'labels': u'Monsanto Co. materials fertilizers & agricultural chemicals',
#   'values': u'mon'},
#  {'labels': u'Monster Beverage consumer staples soft drinks',
#   'values': u'mnst'},
#  {'labels': u"Moody's Corp financials financial exchanges & data",
#   'values': u'mco'},
#  {'labels': u'Morgan Stanley financials investment banking & brokerage',
#   'values': u'ms'},
#  {'labels': u'The Mosaic Company materials fertilizers & agricultural chemicals',
#   'values': u'mos'},
#  {'labels': u'Motorola Solutions Inc. information technology communications equipment',
#   'values': u'msi'},
#  {'labels': u'Murphy Oil energy integrated oil & gas', 'values': u'mur'},
#  {'labels': u'Mylan N.V. health care pharmaceuticals', 'values': u'myl'},
#  {'labels': u'Nasdaq, Inc. financials financial exchanges & data',
#   'values': u'ndaq'},
#  {'labels': u'National Oilwell Varco Inc. energy oil & gas equipment & services',
#   'values': u'nov'},
#  {'labels': u'Navient financials consumer finance', 'values': u'navi'},
#  {'labels': u'NetApp information technology internet software & services',
#   'values': u'ntap'},
#  {'labels': u'Netflix Inc. information technology internet software & services',
#   'values': u'nflx'},
#  {'labels': u'Newell Brands consumer discretionary housewares & specialties',
#   'values': u'nwl'},
#  {'labels': u'Newfield Exploration Co energy oil & gas exploration & production',
#   'values': u'nfx'},
#  {'labels': u'Newmont Mining Corporation materials gold', 'values': u'nem'},
#  {'labels': u'News Corp. Class A consumer discretionary publishing',
#   'values': u'nwsa'},
#  {'labels': u'News Corp. Class B consumer discretionary publishing',
#   'values': u'nws'},
#  {'labels': u'NextEra Energy utilities multi-utilities', 'values': u'nee'},
#  {'labels': u'Nielsen Holdings industrials research & consulting services',
#   'values': u'nlsn'},
#  {'labels': u'Nike consumer discretionary apparel, accessories & luxury goods',
#   'values': u'nke'},
#  {'labels': u'NiSource Inc. utilities multi-utilities', 'values': u'ni'},
#  {'labels': u'Noble Energy Inc energy oil & gas exploration & production',
#   'values': u'nbl'},
#  {'labels': u'Nordstrom consumer discretionary department stores',
#   'values': u'jwn'},
#  {'labels': u'Norfolk Southern Corp. industrials railroads', 'values': u'nsc'},
#  {'labels': u'Northern Trust Corp. financials asset management & custody banks',
#   'values': u'ntrs'},
#  {'labels': u'Northrop Grumman Corp. industrials aerospace & defense',
#   'values': u'noc'},
#  {'labels': u'NRG Energy utilities independent power producers & energy traders',
#   'values': u'nrg'},
#  {'labels': u'Nucor Corp. materials steel', 'values': u'nue'},
#  {'labels': u'Nvidia Corporation information technology semiconductors',
#   'values': u'nvda'},
#  {'labels': u"O'Reilly Automotive consumer discretionary specialty stores",
#   'values': u'orly'},
#  {'labels': u'Occidental Petroleum energy oil & gas exploration & production',
#   'values': u'oxy'},
#  {'labels': u'Omnicom Group consumer discretionary advertising',
#   'values': u'omc'},
#  {'labels': u'ONEOK energy oil & gas storage & transportation',
#   'values': u'oke'},
#  {'labels': u'Oracle Corp. information technology application software',
#   'values': u'orcl'},
#  {'labels': u'PACCAR Inc. industrials construction machinery & heavy trucks',
#   'values': u'pcar'},
#  {'labels': u'Parker-Hannifin industrials industrial machinery',
#   'values': u'ph'},
#  {'labels': u'Patterson Companies health care health care supplies',
#   'values': u'pdco'},
#  {'labels': u'Paychex Inc. information technology internet software & services',
#   'values': u'payx'},
#  {'labels': u'PayPal information technology data processing & outsourced services',
#   'values': u'pypl'},
#  {'labels': u'Pentair Ltd. industrials industrial machinery',
#   'values': u'pnr'},
#  {'labels': u"People's United Financial financials thrifts & mortgage finance",
#   'values': u'pbct'},
#  {'labels': u'PepsiCo Inc. consumer staples soft drinks', 'values': u'pep'},
#  {'labels': u'PerkinElmer health care health care equipment',
#   'values': u'pki'},
#  {'labels': u'Perrigo health care pharmaceuticals', 'values': u'prgo'},
#  {'labels': u'Pfizer Inc. health care pharmaceuticals', 'values': u'pfe'},
#  {'labels': u'PG&E Corp. utilities multi-utilities', 'values': u'pcg'},
#  {'labels': u'Philip Morris International consumer staples tobacco',
#   'values': u'pm'},
#  {'labels': u'Phillips 66 energy oil & gas refining & marketing',
#   'values': u'psx'},
#  {'labels': u'Pinnacle West Capital utilities multi-utilities',
#   'values': u'pnw'},
#  {'labels': u'Pioneer Natural Resources energy oil & gas exploration & production',
#   'values': u'pxd'},
#  {'labels': u'PNC Financial Services financials regional banks',
#   'values': u'pnc'},
#  {'labels': u'Polo Ralph Lauren Corp. consumer discretionary apparel, accessories & luxury goods',
#   'values': u'rl'},
#  {'labels': u'PPG Industries materials specialty chemicals', 'values': u'ppg'},
#  {'labels': u'PPL Corp. utilities electric utilities', 'values': u'ppl'},
#  {'labels': u'Praxair Inc. materials industrial gases', 'values': u'px'},
#  {'labels': u'Priceline.com Inc consumer discretionary internet & direct marketing retail',
#   'values': u'pcln'},
#  {'labels': u'Principal Financial Group financials life & health insurance',
#   'values': u'pfg'},
#  {'labels': u'Procter & Gamble consumer staples personal products',
#   'values': u'pg'},
#  {'labels': u'Progressive Corp. financials property & casualty insurance',
#   'values': u'pgr'},
#  {'labels': u'Prologis real estate industrial reits', 'values': u'pld'},
#  {'labels': u'Prudential Financial financials life & health insurance',
#   'values': u'pru'},
#  {'labels': u'Public Serv. Enterprise Inc. utilities electric utilities',
#   'values': u'peg'},
#  {'labels': u'Public Storage real estate specialized reits', 'values': u'psa'},
#  {'labels': u'Pulte Homes Inc. consumer discretionary homebuilding',
#   'values': u'phm'},
#  {'labels': u'PVH Corp. consumer discretionary apparel, accessories & luxury goods',
#   'values': u'pvh'},
#  {'labels': u'Qorvo information technology semiconductors', 'values': u'qrvo'},
#  {'labels': u'Quanta Services Inc. industrials construction & engineering',
#   'values': u'pwr'},
#  {'labels': u'QUALCOMM Inc. information technology semiconductors',
#   'values': u'qcom'},
#  {'labels': u'Quest Diagnostics health care health care services',
#   'values': u'dgx'},
#  {'labels': u'Range Resources Corp. energy oil & gas exploration & production',
#   'values': u'rrc'},
#  {'labels': u'Raymond James Financial Inc. financials investment banking & brokerage',
#   'values': u'rjf'},
#  {'labels': u'Raytheon Co. industrials aerospace & defense', 'values': u'rtn'},
#  {'labels': u'Realty Income Corporation real estate retail reits',
#   'values': u'o'},
#  {'labels': u'Red Hat Inc. information technology systems software',
#   'values': u'rht'},
#  {'labels': u'Regency Centers Corporation real estate retail reits',
#   'values': u'reg'},
#  {'labels': u'Regeneron health care biotechnology', 'values': u'regn'},
#  {'labels': u'Regions Financial Corp. financials regional banks',
#   'values': u'rf'},
#  {'labels': u'Republic Services Inc industrials environmental & facilities services',
#   'values': u'rsg'},
#  {'labels': u'Reynolds American Inc. consumer staples tobacco',
#   'values': u'rai'},
#  {'labels': u'Robert Half International industrials human resource & employment services',
#   'values': u'rhi'},
#  {'labels': u'Rockwell Automation Inc. industrials electrical components & equipment',
#   'values': u'rok'},
#  {'labels': u'Rockwell Collins industrials aerospace & defense',
#   'values': u'col'},
#  {'labels': u'Roper Technologies industrials industrial conglomerates',
#   'values': u'rop'},
#  {'labels': u'Ross Stores consumer discretionary apparel retail',
#   'values': u'rost'},
#  {'labels': u'Royal Caribbean Cruises Ltd consumer discretionary hotels, resorts & cruise lines',
#   'values': u'rcl'},
#  {'labels': u'Salesforce.com information technology internet software & services',
#   'values': u'crm'},
#  {'labels': u'SCANA Corp utilities multi-utilities', 'values': u'scg'},
#  {'labels': u'Schlumberger Ltd. energy oil & gas equipment & services',
#   'values': u'slb'},
#  {'labels': u'Scripps Networks Interactive Inc. consumer discretionary cable & satellite',
#   'values': u'sni'},
#  {'labels': u'Seagate Technology information technology technology hardware, storage & peripherals',
#   'values': u'stx'},
#  {'labels': u'Sealed Air materials paper packaging', 'values': u'see'},
#  {'labels': u'Sempra Energy utilities multi-utilities', 'values': u'sre'},
#  {'labels': u'Sherwin-Williams materials specialty chemicals',
#   'values': u'shw'},
#  {'labels': u'Signet Jewelers consumer discretionary specialty stores',
#   'values': u'sig'},
#  {'labels': u'Simon Property Group Inc real estate retail reits',
#   'values': u'spg'},
#  {'labels': u'Skyworks Solutions information technology semiconductors',
#   'values': u'swks'},
#  {'labels': u'SL Green Realty real estate office reits', 'values': u'slg'},
#  {'labels': u'Snap-On Inc. consumer discretionary household appliances',
#   'values': u'sna'},
#  {'labels': u'Southern Co. utilities electric utilities', 'values': u'so'},
#  {'labels': u'Southwest Airlines industrials airlines', 'values': u'luv'},
#  {'labels': u'S&P Global, Inc. financials financial exchanges & data',
#   'values': u'spgi'},
#  {'labels': u'Stanley Black & Decker consumer discretionary household appliances',
#   'values': u'swk'},
#  {'labels': u'Staples Inc. consumer discretionary specialty stores',
#   'values': u'spls'},
#  {'labels': u'Starbucks Corp. consumer discretionary restaurants',
#   'values': u'sbux'},
#  {'labels': u'State Street Corp. financials asset management & custody banks',
#   'values': u'stt'},
#  {'labels': u'Stericycle Inc industrials environmental & facilities services',
#   'values': u'srcl'},
#  {'labels': u'Stryker Corp. health care health care equipment',
#   'values': u'syk'},
#  {'labels': u'SunTrust Banks financials regional banks', 'values': u'sti'},
#  {'labels': u'Symantec Corp. information technology application software',
#   'values': u'symc'},
#  {'labels': u'Synchrony Financial financials consumer finance',
#   'values': u'syf'},
#  {'labels': u'Synopsys Inc. information technology application software',
#   'values': u'snps'},
#  {'labels': u'Sysco Corp. consumer staples food distributors',
#   'values': u'syy'},
#  {'labels': u'T. Rowe Price Group financials asset management & custody banks',
#   'values': u'trow'},
#  {'labels': u'Target Corp. consumer discretionary general merchandise stores',
#   'values': u'tgt'},
#  {'labels': u'TE Connectivity Ltd. information technology electronic manufacturing services',
#   'values': u'tel'},
#  {'labels': u'TechnipFMC energy oil & gas equipment & services',
#   'values': u'fti'},
#  {'labels': u'Tesoro Petroleum Co. energy oil & gas refining & marketing',
#   'values': u'tso'},
#  {'labels': u'Texas Instruments information technology semiconductors',
#   'values': u'txn'},
#  {'labels': u'Textron Inc. industrials aerospace & defense', 'values': u'txt'},
#  {'labels': u'Thermo Fisher Scientific health care health care equipment',
#   'values': u'tmo'},
#  {'labels': u'Tiffany & Co. consumer discretionary apparel, accessories & luxury goods',
#   'values': u'tif'},
#  {'labels': u'Time Warner Inc. consumer discretionary cable & satellite',
#   'values': u'twx'},
#  {'labels': u'TJX Companies Inc. consumer discretionary apparel retail',
#   'values': u'tjx'},
#  {'labels': u'Torchmark Corp. financials life & health insurance',
#   'values': u'tmk'},
#  {'labels': u'Total System Services information technology internet software & services',
#   'values': u'tss'},
#  {'labels': u'Tractor Supply Company consumer discretionary specialty stores',
#   'values': u'tsco'},
#  {'labels': u'TransDigm Group industrials aerospace & defense',
#   'values': u'tdg'},
#  {'labels': u'Transocean energy oil & gas drilling', 'values': u'rig'},
#  {'labels': u'The Travelers Companies Inc. financials property & casualty insurance',
#   'values': u'trv'},
#  {'labels': u'TripAdvisor consumer discretionary internet & direct marketing retail',
#   'values': u'trip'},
#  {'labels': u'Twenty-First Century Fox Class A consumer discretionary publishing',
#   'values': u'foxa'},
#  {'labels': u'Twenty-First Century Fox Class B consumer discretionary publishing',
#   'values': u'fox'},
#  {'labels': u'Tyson Foods consumer staples packaged foods & meats',
#   'values': u'tsn'},
#  {'labels': u'UDR Inc real estate residential reits', 'values': u'udr'},
#  {'labels': u'Ulta Salon Cosmetics & Fragrance Inc consumer discretionary specialty stores',
#   'values': u'ulta'},
#  {'labels': u'U.S. Bancorp financials diversified banks', 'values': u'usb'},
#  {'labels': u'Under Armour Class C consumer discretionary apparel, accessories & luxury goods',
#   'values': u'ua'},
#  {'labels': u'Under Armour Class A consumer discretionary apparel, accessories & luxury goods',
#   'values': u'uaa'},
#  {'labels': u'Union Pacific industrials railroads', 'values': u'unp'},
#  {'labels': u'United Continental Holdings industrials airlines',
#   'values': u'ual'},
#  {'labels': u'United Health Group Inc. health care managed health care',
#   'values': u'unh'},
#  {'labels': u'United Parcel Service industrials air freight & logistics',
#   'values': u'ups'},
#  {'labels': u'United Rentals, Inc. industrials trading companies & distributors',
#   'values': u'uri'},
#  {'labels': u'United Technologies industrials aerospace & defense',
#   'values': u'utx'},
#  {'labels': u'Universal Health Services, Inc. health care health care facilities',
#   'values': u'uhs'},
#  {'labels': u'Unum Group financials life & health insurance',
#   'values': u'unm'},
#  {'labels': u'V.F. Corp. consumer discretionary apparel, accessories & luxury goods',
#   'values': u'vfc'},
#  {'labels': u'Valero Energy energy oil & gas refining & marketing',
#   'values': u'vlo'},
#  {'labels': u'Varian Medical Systems health care health care equipment',
#   'values': u'var'},
#  {'labels': u'Ventas Inc real estate health care reits', 'values': u'vtr'},
#  {'labels': u'Verisign Inc. information technology internet software & services',
#   'values': u'vrsn'},
#  {'labels': u'Verisk Analytics industrials research & consulting services',
#   'values': u'vrsk'},
#  {'labels': u'Verizon Communications telecommunication services integrated telecommunication services',
#   'values': u'vz'},
#  {'labels': u'Vertex Pharmaceuticals Inc health care biotechnology',
#   'values': u'vrtx'},
#  {'labels': u'Viacom Inc. consumer discretionary cable & satellite',
#   'values': u'viab'},
#  {'labels': u'Visa Inc. information technology internet software & services',
#   'values': u'v'},
#  {'labels': u'Vornado Realty Trust real estate office reits',
#   'values': u'vno'},
#  {'labels': u'Vulcan Materials materials construction materials',
#   'values': u'vmc'},
#  {'labels': u'Wal-Mart Stores consumer staples hypermarkets & super centers',
#   'values': u'wmt'},
#  {'labels': u'Walgreens Boots Alliance consumer staples drug retail',
#   'values': u'wba'},
#  {'labels': u'The Walt Disney Company consumer discretionary cable & satellite',
#   'values': u'dis'},
#  {'labels': u'Waste Management Inc. industrials environmental & facilities services',
#   'values': u'wm'},
#  {'labels': u'Waters Corporation health care health care distributors',
#   'values': u'wat'},
#  {'labels': u'Wec Energy Group Inc utilities electric utilities',
#   'values': u'wec'},
#  {'labels': u'Wells Fargo financials diversified banks', 'values': u'wfc'},
#  {'labels': u'Welltower Inc. real estate health care reits', 'values': u'hcn'},
#  {'labels': u'Western Digital information technology technology hardware, storage & peripherals',
#   'values': u'wdc'},
#  {'labels': u'Western Union Co information technology internet software & services',
#   'values': u'wu'},
#  {'labels': u'WestRock Company materials paper packaging', 'values': u'wrk'},
#  {'labels': u'Weyerhaeuser Corp. real estate specialized reits',
#   'values': u'wy'},
#  {'labels': u'Whirlpool Corp. consumer discretionary household appliances',
#   'values': u'whr'},
#  {'labels': u'Whole Foods Market consumer staples food retail',
#   'values': u'wfm'},
#  {'labels': u'Williams Cos. energy oil & gas storage & transportation',
#   'values': u'wmb'},
#  {'labels': u'Willis Towers Watson financials insurance brokers',
#   'values': u'wltw'},
#  {'labels': u'Wyndham Worldwide consumer discretionary hotels, resorts & cruise lines',
#   'values': u'wyn'},
#  {'labels': u'Wynn Resorts Ltd consumer discretionary casinos & gaming',
#   'values': u'wynn'},
#  {'labels': u'Xcel Energy Inc utilities multi-utilities', 'values': u'xel'},
#  {'labels': u'Xerox Corp. information technology technology hardware, storage & peripherals',
#   'values': u'xrx'},
#  {'labels': u'Xilinx Inc information technology semiconductors',
#   'values': u'xlnx'},
#  {'labels': u'XL Capital financials property & casualty insurance',
#   'values': u'xl'},
#  {'labels': u'Xylem Inc. industrials industrial machinery', 'values': u'xyl'},
#  {'labels': u'Yum! Brands Inc consumer discretionary restaurants',
#   'values': u'yum'},
#  {'labels': u'Zimmer Biomet Holdings health care health care equipment',
#   'values': u'zbh'},
#  {'labels': u'Zions Bancorp financials regional banks', 'values': u'zion'},
#  {'labels': u'Zoetis health care pharmaceuticals', 'values': u'zts'}]

# %%
tickersshort = tickers[:10]
tickersmedium = tickers[:50]
tickersmediumlarge = tickers[:300]

# %% [markdown]
# ## Scraping marketwatch Data Using Beautiful Soup

# %% [markdown]
# ### Formatting all the values to numerical

# %%
def format(list):
    newlist=[]
    posornegnumber = 1
    for text in list:
        if text.endswith(')'):
            text = text[1:-1] # remove the parentheses
            posornegnumber = -1
            
        if text.endswith('%'):
#             Then please make it into comma float
            endtext = float(text[:-1])/100.0 * posornegnumber 
        elif text.endswith('B'):
#             Then please times 1000000000
#             Change it into integer
            endtext = int(float(text[:-1])*1000000000)* posornegnumber 
        elif text.endswith('M'):
#             Then please times 1000000
#             Change it into integer
            endtext = int(float(text[:-1])*1000000)* posornegnumber 
        elif ',' in text:
#             Then please remove the ,
#             Then change it into int
            endtext = int(float(text.replace(",","")))* posornegnumber 

        elif text.endswith('-'):
#             Insert 0
            endtext = 0
        else:
#             change to float
            endtext = float(text)* posornegnumber 
        newlist.append(endtext)
    return newlist

# %% [markdown]
# ### Extracting Financial Reporting (Balance Sheet and Income Statement)

# %%
# %%time
import pandas as pd
from urllib import urlopen
from bs4 import BeautifulSoup

dflist = []

for ticker in ['tsla']: 
    try:
        urlfinancials = 'http://www.marketwatch.com/investing/stock/'+ticker+'/financials'
        urlbalancesheet = 'http://www.marketwatch.com/investing/stock/'+ticker+'/financials/balance-sheet'

        text_soup_financials = BeautifulSoup(urlopen(urlfinancials).read()) #read in
        text_soup_balancesheet = BeautifulSoup(urlopen(urlbalancesheet).read()) #read in

        # Income statement
        titlesfinancials = text_soup_financials.findAll('td', {'class': 'rowTitle'})
        epslist=[]
        netincomelist = []
        longtermdebtlist = [] 
        interestexpenselist = []
        ebitdalist= []

        for title in titlesfinancials:
            if 'EPS (Basic)' in title.text:
                epslist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Net Income' in title.text:
                netincomelist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Interest Expense' in title.text:
                interestexpenselist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'EBITDA' in title.text:
                ebitdalist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])


        # Balance sheet
        titlesbalancesheet = text_soup_balancesheet.findAll('td', {'class': 'rowTitle'})
        equitylist=[]
        for title in titlesbalancesheet:
            if 'Total Shareholders\' Equity' in title.text:
                equitylist.append( [td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Long-Term Debt' in title.text:
                longtermdebtlist.append( [td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])

        # Variables        
        eps = epslist[0]
        epsgrowth = epslist[1]
        netincome = netincomelist[0]
        shareholderequity = equitylist[0]
        roa = equitylist[1]

        longtermdebt = longtermdebtlist[0]
        interestexpense = interestexpenselist[0]
        ebitda = ebitdalist[0]
        # Don't forget to add in roe, interest coverage ratio

        ## Make it into Dataframes
        df= pd.DataFrame({'eps': eps,'epsgrowth': epsgrowth,'netincome': netincome,'shareholderequity': shareholderequity,'roa': 
                      roa,'longtermdebt': longtermdebt,'interestexpense': interestexpense,'ebitda': ebitda},index=[2012,2013,2014,2015,2016])

        # Format all the number in dataframe
        dfformatted = df.apply(format)

        # Adding roe, interest coverage ratio
        dfformatted['roe'] = dfformatted.netincome/dfformatted.shareholderequity
        dfformatted['interestcoverageratio'] = dfformatted.ebitda/dfformatted.interestexpense

    #     Insert ticker and df
        dflist.append((ticker,dfformatted))
    except:
        print(ticker,' ticker is not found')
# Out:
# Wall time: 4.26 s

# %%
dflist[0][1].reset_index()
# Out:
#    index     ebitda   eps  epsgrowth  interestexpense  longtermdebt  \
# 0   2012 -365460000 -3.69     0.0000           254000     411460000
# 1   2013  -44800000 -0.62     0.8320         22130000     598970000
# 2   2014  -11440000 -2.36    -2.8065        100890000    1850000000
# 3   2015 -352640000 -6.93    -1.9364        118850000    2280000000
# 4   2016 -256560000 -4.68     0.3247        198810000    7390000000
#
#    netincome     roa  shareholderequity       roe  interestcoverageratio
# 0 -396210000  0.1119          124700000 -3.177306           -1438.818898
# 1  -74010000  0.2760          667120000 -0.110940              -2.024401
# 2 -294040000  0.1559          911710000 -0.322515              -0.113391
# 3 -888660000  0.1346         1090000000 -0.815284              -2.967101
# 4 -773050000  0.2097         4750000000 -0.162747              -1.290478

# %%
len(dflist)
# Out:
# 10

# %% [markdown]
# ## Time
# 40 seconds for 10 tickers
#
# 3 minutes for 50 tickers

# %% [markdown]
# ## Determining legibility
# Find whether this particular stocks is legitimate using this and filter accordingly
#     1. EPS increases over the year (consistent)
#     2. ROE > 0.15
#     3. ROA > 0.07 (also consider debt to equity cause Assets = liabilities + equity)
#     4. Long term debt < 5 * income
#     5. Interest Coverage Ratio > 3

# %%
def eligibilitycheck(df):
    ticker,dfformatted = df
    
    legiblestock = True
    reasonlist=[]

    # EPS increases over the year (consistent)
    for growth in dfformatted.epsgrowth:
        if growth<0:
            legiblestock = False
            reasonlist.append('there is negative growth '+str(growth))
            break
    # ROE > 0.15
    if dfformatted.roe.mean()<0.13:
            legiblestock = False
            reasonlist.append('roe mean is less than 0.13 '+ str(dfformatted.roe.mean()))
    # ROA > 0.07 (also consider debt to equity cause Assets = liabilities + equity)
    if dfformatted.roa.mean()<0.07:
            legiblestock = False
            reasonlist.append('roa mean is less than 0.07 ' + str(dfformatted.roa.mean()))
    # Long term debt < 5 * income
    if dfformatted.longtermdebt.tail(1).values[0]>5*dfformatted.netincome.tail(1).values[0]:
            legiblestock = False
            reasonlist.append('longtermdebt is 5 times the netincome ')
    # Interest Coverage Ratio > 3
    if dfformatted.interestcoverageratio.tail(1).values[0]<3:
            legiblestock = False
            reasonlist.append('Interestcoverageratio is less than 3 ')
#     print ticker,legiblestock,reasonlist
    return ticker,legiblestock

# %%
dflist[:2]
# Out:
# [(u'mmm',
#             ebitda   eps  epsgrowth  interestexpense  longtermdebt   netincome  \
#   2012  7760000000  6.40     0.0000        221000000    2990000000  4510000000
#   2013  8029999999  6.83     0.0672                0    2240000000  4720000000
#   2014  8529999999  7.63     0.1171        101000000    3230000000  5000000000
#   2015  8310000000  7.73     0.0125        117000000    2000000000  4840000000
#   2016  8490000000  8.35     0.0809        207000000    3940000000  5060000000
#
#            roa  shareholderequity       roe  interestcoverageratio
#   2012  0.7646        71720000000  0.062883              35.113122
#   2013  0.7871        87310000000  0.054060                    inf
#   2014  0.8040       103860000000  0.048142              84.455446
#   2015  0.8160       120330000000  0.040223              71.025641
#   2016  0.8301       139040000000  0.036392              41.014493  ),
#  (u'abt',
#             ebitda   eps  epsgrowth  interestexpense  longtermdebt   netincome  \
#   2012  4790000000  3.76     0.0000        409000000    2990000000   533000000
#   2013  3870000000  1.64    -0.5638         47000000    2240000000  1970000000
#   2014  4390000000  1.50    -0.0858        164000000    3230000000  1710000000
#   2015  4420000000  1.77     0.1820        178000000    2000000000  2590000000
#   2016  4600000000  0.93    -0.4739        304000000    3940000000  1060000000
#
#            roa  shareholderequity       roe  interestcoverageratio
#   2012  0.7646        71720000000  0.007432              11.711491
#   2013  0.7871        87310000000  0.022563              82.340426
#   2014  0.8040       103860000000  0.016464              26.768293
#   2015  0.8160       120330000000  0.021524              24.831461
#   2016  0.8301       139040000000  0.007624              15.131579  )]

# %%
selectiondflist = []
for df in dflist:
    if eligibilitycheck(df)[1]:
        selectiondflist.append(df)
# Out:
# mmm False ['roe mean is less than 0.13 0.0483401071703']
# abt False ['there is negative growth -0.5638', 'roe mean is less than 0.13 0.0151214555543']
# abbv False ['there is negative growth -0.2287', 'roe mean is less than 0.13 0.0445496491725']
# acn False ['there is negative growth -0.0866', 'roe mean is less than 0.13 0.0338117326132']
# atvi False ['there is negative growth -0.0495', 'roe mean is less than 0.13 0.00983340539427']
# ayi False ['roe mean is less than 0.13 0.00172609663005', 'longtermdebt is 5 times the netincome ']
# adbe False ['there is negative growth -0.6548', 'roe mean is less than 0.13 0.00623277670333']
# amd False ['there is negative growth -3.77', 'roe mean is less than 0.13 -0.0060686317473', 'longtermdebt is 5 times the netincome ', 'Interestcoverageratio is less than 3 ']
# aap False ['there is negative growth -0.0444', 'roe mean is less than 0.13 0.00436678953041', 'longtermdebt is 5 times the netincome ']
# aes False ['there is negative growth -0.6113', 'roe mean is less than 0.13 -0.00674281890558', 'longtermdebt is 5 times the netincome ', 'Interestcoverageratio is less than 3 ']
# a False ['there is negative growth -0.3595', 'roe mean is less than 0.13 0.00722846637955', 'longtermdebt is 5 times the netincome ']
# apd False ['there is negative growth -0.0301', 'roe mean is less than 0.13 0.0115816617688']
# akam False ['there is negative growth -0.0374', 'roe mean is less than 0.13 0.00287316912654', 'longtermdebt is 5 times the netincome ']
# alk False ['there is negative growth -0.003', 'roe mean is less than 0.13 0.00579024761713']
# alb False ['there is negative growth -0.487', 'roe mean is less than 0.13 0.00365881935197', 'longtermdebt is 5 times the netincome ']
# alxn False ['there is negative growth -0.0373', 'roe mean is less than 0.13 0.00336882876941', 'longtermdebt is 5 times the netincome ']
# algn False ['there is negative growth -0.0055', 'roe mean is less than 0.13 0.00110399324542', 'longtermdebt is 5 times the netincome ']
# alle False ['there is negative growth -0.8507', 'roe mean is less than 0.13 0.0016807212366', 'longtermdebt is 5 times the netincome ']
# agn False ['there is negative growth -7.8442', 'roe mean is less than 0.13 -0.0107004071346', 'longtermdebt is 5 times the netincome ']
# ads False ['there is negative growth -0.1358', 'roe mean is less than 0.13 0.00483543046462', 'longtermdebt is 5 times the netincome ']
# lnt False ['there is negative growth -0.0289', 'roe mean is less than 0.13 0.00378969415257', 'longtermdebt is 5 times the netincome ']
# googl True []
# goog True []
# mo False ['roe mean is less than 0.13 0.0608736598712']
# amzn False ['there is negative growth -1.8667', 'roe mean is less than 0.13 -0.00560019122003', 'longtermdebt is 5 times the netincome ']
# aee False ['roe mean is less than 0.13 -0.00696487137852', 'longtermdebt is 5 times the netincome ']
# aal False ['there is negative growth -1.0089', 'roe mean is less than 0.13 -0.0314840526192', 'longtermdebt is 5 times the netincome ']
# aep False ['there is negative growth -0.6589', 'roe mean is less than 0.13 0.0138964391044', 'longtermdebt is 5 times the netincome ']
# awk False ['there is negative growth -0.0113', 'roe mean is less than 0.13 0.00418117338301', 'longtermdebt is 5 times the netincome ']
# ame False ['there is negative growth -0.1057', 'roe mean is less than 0.13 0.00530887753749', 'longtermdebt is 5 times the netincome ']
# amgn False ['roe mean is less than 0.13 0.0563433209072']
# aph False ['roe mean is less than 0.13 0.00688195553813']
# apc False ['there is negative growth -0.6675', 'roe mean is less than 0.13 -0.00948265086561', 'longtermdebt is 5 times the netincome ']
# adi False ['there is negative growth -0.0822', 'roe mean is less than 0.13 0.00696840356538']
# apa False ['there is negative growth -3.5401', 'roe mean is less than 0.13 -0.0161918005086', 'longtermdebt is 5 times the netincome ']
# aapl False ['there is negative growth -0.1033']

# %%
len(dflist)
# Out:
# 36

# %%
len(selectiondflist)
# Out:
# 2

# %%
# What are the tickers of these?
print [x[0] for x in selectiondflist]
# Out:
# [u'googl', u'goog']

# %% [markdown]
# ## Scraping for latest shareprice using selectiondflist

# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import Series, DataFrame


days_per_year = 365.24

# start = datetime.datetime.now()-datetime.timedelta(days=(5*days_per_year))
start = datetime.datetime.now()-datetime.timedelta(days=1)
end = datetime.datetime.now()

# To pull individual stock
# df = web.DataReader("AAPL", 'google', start, end)
# df.tail()

# To pull group stocks
dfcomp = web.DataReader(dfrank.index,'google',
                               start=start, 
                               end=end)['Close']

# %% [markdown]
# # Using selectiondflist to calculate stocks price value
#
# Outputs:
# 1. Ranking of each company in terms of return rate given the value investing methodology
#     a. Find EPS Annual Compounded Growth Rate
#     b. Estimate EPS 10 years from now
#     c. Estimate stock price 10 years from now (Stock Price EPS * Average PE)
#     d. Determine target by price today based on returns(discount rate 15%/20%)
#     e. Add margin of safety (Safety net 15%)

# %%
import numpy as np
dfprice = pd.DataFrame(columns =['ticker','annualgrowthrate','lasteps','futureeps'])
i=0
for tuple in selectiondflist:
    ticker, df = tuple
    
    # Find EPS Annual Compounded Growth Rate
    annualgrowthrate =  df.epsgrowth.mean() #growth rate
    
    # Estimate stock price 10 years from now (Stock Price EPS * Average PE)
    lasteps = df.eps.tail(1).values[0] #presentvalue
    years  = 10 #period
    
    futureeps = abs(np.fv(annualgrowthrate,years,0,lasteps))
        
    dfprice.loc[i] = [ticker,annualgrowthrate,lasteps,futureeps]
    i+=1
    
dfprice.set_index('ticker',inplace=True)

# %%
dfprice['lastshareprice']=dfcomp.tail().T.values
dfprice['peratio'] = dfprice['lastshareprice']/dfprice['lasteps']
dfprice['futureshareprice'] = dfprice['futureeps']*dfprice['peratio']

# %%
discountrate = 0.20
margin = 0.15

dfprice['presentshareprice'] = abs(np.pv(discountrate,years,0,fv=dfprice['futureshareprice']))
dfprice['marginalizedprice'] = dfprice['presentshareprice']*(1-0.15)

# %%
dfprice
# Out:
#         annualgrowthrate  lasteps  futureeps  lastshareprice    peratio  \
# ticker
# googl            0.11778    28.32  86.229645          965.59  34.095692
# goog             0.11778    28.32  86.229645          986.09  34.819562
#
#         futureshareprice  presentshareprice  marginalizedprice
# ticker
# googl        2940.059410         474.836009         403.610607
# goog         3002.478467         484.917035         412.179480
