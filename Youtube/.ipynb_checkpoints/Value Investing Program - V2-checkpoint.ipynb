# %% [markdown]
# # Value Investing Program
# # Introduction
#
# Inspired by Sean Seah Book -- Gone Fishing with Warren Buffetthttp://www.aceprofitsacademy.com/wp-content/uploads/2016/09/Gone-Fishing-with-Buffett.pdf
#
# In here we are going to try to scrape financial data:
# Input: List of the companies
#
# Web scraping:
# * Find the shareprice by year and the following metrics:
#     * EPS
#     * ROE
#     * ROA
#     * Long term debt
#     * Total Income
#     * Debt to Equity
#     * Interest Coverage Ratio
#
# Methods:
# * Given list of the companies, find out the feasibility to invest
#     * Been in market minimal 10 years
#     * Have the track records (EPS per year)
#     * Have efficiency (ROE > 15%) -- Net income / shareholder equity
#     * Determine manipulation (ROA > 7%) -- Net income / Total Asset
#     * Have small long term debt (Long term debt <5* total income)
#     * Low Debt to Equity
#     * Ability to pay interest: (Interest Coverage Ratio >3) -- EBIT / Interest expenses
#
# Outputs:
# * Ranking of each company in terms of return rate given the value investing methodology
#     * Find EPS Annual Compounded Growth Rate
#     * Estimate EPS 10 years from now
#     * Estimate stock price 10 years from now (Stock Price EPS * Average PE)
#     * Determine target by price today based on returns(discount rate 15%/20%)
#     * Add margin of safety (Safety net 15%)
#
# Additional:
# * Qualitative Assessment of the companies
#     * Advantages in business (product differentiation, branding, low price producer, high switching cost, legal barriers to entry)
#     * Ability of foolhardy management (even a fool can run)
#     * Avoid price competitive business

# %% [markdown]
# # Initiating all parameters/addresses

# %%
import pandas as pd
import pickle
import random
import datetime
import pandas_datareader.data as web
import numpy as np

urlwikisp500 = 'http://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
urlmarketwatch = 'http://www.marketwatch.com/investing/stock/'

locblacklist = 'C:/Users/vintatan/Desktop/Investment/blacklist.csv'

locsp500anddata = "C:/Users/vintatan/Desktop/Investment/SP500andData.csv"
locfinancialreportpickle= 'C:/Users/vintatan/Desktop/Investment/financialreport.pickle'
locstocksanalysis = 'C:/Users/vintatan/Desktop/Investment/stocksanalysis.csv'

locrussellanddata = "C:/Users/vintatan/Desktop/Investment/RussellandData.csv"
locpicklerussellfinancialreport= 'C:/Users/vintatan/Desktop/Investment/russellfinancialreport.pickle'
locrussellstocksanalysis = 'C:/Users/vintatan/Desktop/Investment/russellstocksanalysis.csv'

analyse_sp_or_russell = 'russell'
filter_applies= True

if (analyse_sp_or_russell=='russell'):
    locfinancialreportpickle=locpicklerussellfinancialreport
    locstocksanalysis=locrussellstocksanalysis
    
# Read blacklist

# Blacklist list to remove from calculation
import csv
blacklist =[]
with open(locblacklist) as f:
    reader = csv.reader(f)
    for row in reader:
        blacklist.append(row)
blacklist = blacklist[0]

# %% [markdown]
# # Web scraping Russell Data Using Beautiful Soup

# %%
# Reading russel stocks plans and getting the 2000 stocks
dfrussel = pd.read_html('http://www.kibot.com/Historical_Data/Russell_3000_Historical_Intraday_Data.aspx', flavor='bs4')[1];
dfrussel.columns = dfrussel.iloc[0]
dfrussel = dfrussel.reindex(dfrussel.index.drop(0))
dfrussel = dfrussel.drop('#',axis=1)
dfrussel.set_index('Symbol',inplace=True)
dfrussel.dropna(inplace=True)

# %%
dfrussel.index
# Out:
# Index([u'A', u'AA', u'AAN', u'AAON', u'AAP', u'AAPL', u'AAT', u'AAWW', u'ABAX',
#        u'ABBV',
#        ...
#        u'ZBRA', u'ZEUS', u'ZGNX', u'ZION', u'ZIOP', u'ZIXI', u'ZN', u'ZNGA',
#        u'ZTS', u'ZUMZ'],
#       dtype='object', name=u'Symbol', length=2516)

# %%
tickersrussel = dfrussel.index

# %%
dfrussel['labels'] = dfrussel[['Description','Industry', 'Sector']].apply(lambda x: ' '.join(x), axis=1)
dfrussel.to_csv(locrussellanddata)

# %% [markdown]
# ## Scraping Wikipedia SP500 Data Using Beautiful Soup

# %%
import bs4 as bs
import pickle
import requests
import pandas as pd

# This will keep tickers + gics industries & sub industries
## Time
# 40 seconds for 10 tickers
# 3 minutes for 50 tickers

def save_sp500_stocks_info():
    resp = requests.get(urlwikisp500)
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    stocks_info=[]
    tickers = []
    securities = []
    gics_industries = []
    gics_sub_industries = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        security = row.findAll('td')[1].text
        gics_industry = row.findAll('td')[3].text
        gics_sub_industry = row.findAll('td')[4].text

        tickers.append(ticker.lower())
        securities.append(security)
        gics_industries.append(gics_industry.lower())
        gics_sub_industries.append(gics_sub_industry.lower())
    
    stocks_info.append(tickers)
    stocks_info.append(securities)
    stocks_info.append(gics_industries)
    stocks_info.append(gics_sub_industries)
    return stocks_info

stocks_info = save_sp500_stocks_info()
stocks_info_df = pd.DataFrame(stocks_info).T
stocks_info_df.columns=['tickers','security','gics_industry','gics_sub_industry']
stocks_info_df.set_index('tickers',inplace=True)

# Extract just the tickers list
tickers= stocks_info[0]

# %%
stocks_info_df['labels'] = stocks_info_df[['security', 'gics_industry','gics_sub_industry']].apply(lambda x: ' '.join(x), axis=1)
stocks_info_df.to_csv(locsp500anddata)

# %%
# Create a list of dict based on tickers and labels
dictlist = []
for index, row in stocks_info_df.iterrows():
    dictlist.append({'value':index, 'label':row['labels']})

# %% [markdown]
# ## Merging Russell and SP500

# %%
dfrussel=pd.read_csv('C:/Users/vintatan/Desktop/Investment/RussellandData.csv',index_col='Symbol')

# %%
dfrussel=pd.read_csv('C:/Users/vintatan/Desktop/Investment/RussellandData.csv',index_col='Symbol')
dfrussel.index = dfrussel.index.str.lower()
dfrussel['tickers'] = dfrussel.Description.str.title()
dfrussel['gics_industry'] = dfrussel.Sector.str.lower()
dfrussel['gics_sub_industry'] = dfrussel.Industry.str.lower()
dfrussel['labels'] = dfrussel[['gics_industry','gics_sub_industry']].apply(lambda x: ' '.join(x), axis=1)

dictlist = []
for index, row in dfrussel.iterrows():
    print("there you go")
    dictlist.append({'value':row['tickers'], 'label':row['labels']})
dictlist
# Out:
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# there you go
# [{'label': 'capital goods biotechnology: laboratory analytical instruments',
#   'value': 'Agilent Technologies, Inc.'},
#  {'label': 'capital goods metal fabrications', 'value': 'Alcoa Corporation'},
#  {'label': 'technology diversified commercial services',
#   'value': "Aaron'S, Inc."},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Aaon, Inc.'},
#  {'label': 'consumer services other specialty stores',
#   'value': 'Advance Auto Parts Inc'},
#  {'label': 'technology computer manufacturing', 'value': 'Apple Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'American Assets Trust, Inc.'},
#  {'label': 'transportation transportation services',
#   'value': 'Atlas Air Worldwide Holdings'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Abaxis, Inc.'},
#  {'label': 'health care major pharmaceuticals', 'value': 'Abbvie Inc.'},
#  {'label': 'health care other pharmaceuticals',
#   'value': 'Amerisourcebergen Corporation (Holding Co)'},
#  {'label': 'finance major banks', 'value': 'Ameris Bancorp'},
#  {'label': 'consumer services publishing',
#   'value': 'Cambium Learning Group, Inc.'},
#  {'label': 'consumer services other consumer services',
#   'value': 'The Advisory Board Company'},
#  {'label': 'consumer durables automotive aftermarket',
#   'value': 'Asbury Automotive Group Inc'},
#  {'label': 'finance diversified commercial services',
#   'value': 'Abm Industries Incorporated'},
#  {'label': 'health care medical/dental instruments', 'value': 'Abiomed, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Arbor Realty Trust'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Abbott Laboratories'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Acadia Pharmaceuticals Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'American Campus Communities Inc'},
#  {'label': 'consumer durables publishing', 'value': 'Acco Brands Corporation'},
#  {'label': 'health care other pharmaceuticals', 'value': 'Aceto Corporation'},
#  {'label': 'technology computer peripherals', 'value': 'Acorn Energy, Inc.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Arch Capital Group Ltd.'},
#  {'label': 'health care medical specialities',
#   'value': 'Acadia Healthcare Company, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Achillion Pharmaceuticals, Inc.'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'Aci Worldwide, Inc.'},
#  {'label': 'technology industrial machinery/components',
#   'value': 'Axcelis Technologies, Inc.'},
#  {'label': 'consumer services military/government/technical',
#   'value': 'Aecom'},
#  {'label': 'miscellaneous business services', 'value': 'Accenture Plc'},
#  {'label': 'health care biotechnology: biological products (no diagnostic substances)',
#   'value': 'Acorda Therapeutics, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Ares Commercial Real Estate Corporation'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Acelrx Pharmaceuticals, Inc.'},
#  {'label': 'miscellaneous multi-sector companies',
#   'value': 'Acacia Research Corporation'},
#  {'label': 'manufacturing semiconductors and related devices',
#   'value': 'Actel Corp'},
#  {'label': 'healthcare drug delivery', 'value': 'Acura Pharmaceuticals, Inc.'},
#  {'label': 'technology edp services', 'value': 'Acxiom Corporation'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'Adobe Systems Incorporated'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Agree Realty Corporation'},
#  {'label': 'basic industries major chemicals',
#   'value': 'Advanced Emissions Solutions, Inc.'},
#  {'label': 'technology semiconductors', 'value': 'Analog Devices, Inc.'},
#  {'label': 'consumer non-durables packaged foods',
#   'value': 'Archer-Daniels-Midland Company'},
#  {'label': 'technology edp services',
#   'value': 'Automatic Data Processing, Inc.'},
#  {'label': 'miscellaneous business services',
#   'value': 'Alliance Data Systems Corporation'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'Autodesk, Inc.'},
#  {'label': 'public utilities telecommunications equipment',
#   'value': 'Adtran, Inc.'},
#  {'label': 'health care medical/nursing services',
#   'value': 'Addus Homecare Corporation'},
#  {'label': 'energy oil refining/marketing',
#   'value': 'Adams Resources & Energy, Inc.'},
#  {'label': 'public utilities power generation', 'value': 'Ameren Corporation'},
#  {'label': 'basic industries water supply', 'value': 'Aegion Corp'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Advanced Energy Industries, Inc.'},
#  {'label': 'finance life insurance',
#   'value': 'American Equity Investment Life Holding Company'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'American Eagle Outfitters, Inc.'},
#  {'label': 'public utilities electric utilities: central',
#   'value': 'American Electric Power Company, Inc.'},
#  {'label': 'basic industries electric utilities: central',
#   'value': 'The Aes Corporation'},
#  {'label': 'health care medical specialities', 'value': 'Aetna Inc.'},
#  {'label': 'finance savings institutions',
#   'value': 'Astoria Financial Corporation'},
#  {'label': 'health care medical/nursing services',
#   'value': 'Almost Family Inc'},
#  {'label': 'healthcare biotechnology', 'value': 'Affymax, Inc.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'American Financial Group, Inc.'},
#  {'label': 'finance accident &health insurance',
#   'value': 'Aflac Incorporated'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Amtrust Financial Services, Inc.'},
#  {'label': 'basic industries precious metals',
#   'value': 'First Majestic Silver Corp.'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Agco Corporation'},
#  {'label': 'finance specialty insurers',
#   'value': 'Argo Group International Holdings, Ltd.'},
#  {'label': 'finance finance companies',
#   'value': 'Federal Agricultural Mortgage Corporation'},
#  {'label': 'health care major pharmaceuticals', 'value': 'Allergan Plc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Agnc Investment Corp.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Assured Guaranty Ltd.'},
#  {'label': 'basic industries engineering & construction',
#   'value': 'Argan, Inc.'},
#  {'label': 'technology edp services', 'value': 'Agilysys, Inc.'},
#  {'label': 'consumer services newspapers/magazines',
#   'value': 'A.H. Belo Corporation'},
#  {'label': 'finance real estate', 'value': 'Armada Hoffler Properties, Inc.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Aspen Insurance Holdings Limited'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Ashford Hospitality Trust Inc'},
#  {'label': 'finance finance/investors services',
#   'value': 'Arlington Asset Investment Corp'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'American International Group, Inc.'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Altra Industrial Motion Corp.'},
#  {'label': 'basic industries textiles',
#   'value': 'Albany International Corporation'},
#  {'label': 'health care medical specialities',
#   'value': 'Alliance Healthcare Services, Inc.'},
#  {'label': 'capital goods aerospace', 'value': 'Aar Corp.'},
#  {'label': 'consumer durables industrial specialties',
#   'value': 'Applied Industrial Technologies, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Apartment Investment And Management Company'},
#  {'label': 'finance accident &health insurance', 'value': 'Assurant, Inc.'},
#  {'label': 'finance specialty insurers', 'value': 'Arthur J. Gallagher & Co.'},
#  {'label': 'miscellaneous business services',
#   'value': 'Akamai Technologies, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Acadia Realty Trust'},
#  {'label': 'health care major pharmaceuticals', 'value': 'Akorn, Inc.'},
#  {'label': 'basic industries steel/iron ore',
#   'value': 'Ak Steel Holding Corporation'},
#  {'label': 'technology diversified commercial services',
#   'value': 'Air Lease Corporation'},
#  {'label': 'basic industries major chemicals',
#   'value': 'Albemarle Corporation'},
#  {'label': 'consumer non-durables farming/seeds/milling',
#   'value': 'Alico, Inc.'},
#  {'label': 'emerging markets bond wisdomtree',
#   'value': 'Wisdomtree Asia Local Debt Fund'},
#  {'label': 'public utilities power generation', 'value': 'Allete, Inc.'},
#  {'label': 'finance real estate',
#   'value': 'Alexander & Baldwin Holdings, Inc.'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Alamo Group, Inc.'},
#  {'label': 'health care industrial specialties',
#   'value': 'Align Technology, Inc.'},
#  {'label': 'transportation air freight/delivery services',
#   'value': 'Allegiant Travel Company'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Alimera Sciences, Inc.'},
#  {'label': 'basic materials oil & gas refining & marketing',
#   'value': 'Alon Usa Energy, Inc. Common St'},
#  {'label': 'transportation air freight/delivery services',
#   'value': 'Alaska Air Group, Inc.'},
#  {'label': 'health care major pharmaceuticals', 'value': 'Alkermes Plc'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Allstate Corporation (The)'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Alnylam Pharmaceuticals, Inc.'},
#  {'label': 'basic industries precious metals', 'value': 'Alio Gold Inc.'},
#  {'label': 'capital goods electrical products',
#   'value': 'Analogic Corporation'},
#  {'label': 'health care biotechnology: in vitro & in vivo diagnostic substances',
#   'value': 'Alere Inc.'},
#  {'label': 'public utilities telecommunications equipment',
#   'value': 'Alaska Communications Systems Group, Inc.'},
#  {'label': 'capital goods auto parts:o.e.m.',
#   'value': 'Allison Transmission Holdings, Inc.'},
#  {'label': 'capital goods auto parts:o.e.m.', 'value': 'Autoliv, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': "Alexander'S, Inc."},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Alexion Pharmaceuticals, Inc.'},
#  {'label': 'public utilities natural gas distribution',
#   'value': 'Antero Midstream Partners Lp'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Amag Pharmaceuticals, Inc.'},
#  {'label': 'technology semiconductors', 'value': 'Applied Materials, Inc.'},
#  {'label': 'technology semiconductors', 'value': 'Ambarella, Inc.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Ambac Financial Group, Inc.'},
#  {'label': 'consumer services television services',
#   'value': 'Amc Networks Inc.'},
#  {'label': 'technology semiconductors',
#   'value': 'Advanced Micro Devices, Inc.'},
#  {'label': 'consumer durables metal fabrications', 'value': 'Amtek, Inc.'},
#  {'label': 'health care medical/nursing services', 'value': 'Amedisys Inc'},
#  {'label': 'finance investment managers',
#   'value': 'Affiliated Managers Group, Inc.'},
#  {'label': 'health care biotechnology: biological products (no diagnostic substances)',
#   'value': 'Amgen Inc.'},
#  {'label': 'technology semiconductors', 'value': 'Amkor Technology, Inc.'},
#  {'label': 'technology professional services',
#   'value': 'Amn Healthcare Services Inc'},
#  {'label': 'finance major banks',
#   'value': 'American National Bankshares, Inc.'},
#  {'label': 'finance investment managers',
#   'value': 'Ameriprise Financial Services, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Ampio Pharmaceuticals, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Amphastar Pharmaceuticals, Inc.'},
#  {'label': 'basic industries engineering & construction',
#   'value': 'Ameresco, Inc.'},
#  {'label': 'health care biotechnology: commercial physical & biological resarch',
#   'value': 'Albany Molecular Research, Inc.'},
#  {'label': 'basic industries major chemicals', 'value': 'Amyris, Inc.'},
#  {'label': 'consumer durables metal fabrications',
#   'value': 'American Superconductor Corporation'},
#  {'label': 'finance property-casualty insurers', 'value': 'Amerisafe, Inc.'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'American Software, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'American Tower Corporation (Reit)'},
#  {'label': 'finance investment bankers/brokers/service',
#   'value': 'Td Ameritrade Holding Corporation'},
#  {'label': 'basic industries forest products',
#   'value': 'American Woodmark Corporation'},
#  {'label': 'consumer services catalog/specialty distribution',
#   'value': 'Amazon.Com, Inc.'},
#  {'label': 'consumer durables automotive aftermarket',
#   'value': 'Autonation, Inc.'},
#  {'label': 'finance life insurance',
#   'value': 'American National Insurance Company'},
#  {'label': 'finance savings institutions',
#   'value': 'Access National Corporation'},
#  {'label': 'consumer services farming/seeds/milling',
#   'value': 'The Andersons, Inc.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'Abercrombie & Fitch Company'},
#  {'label': 'consumer services advertising', 'value': "Angie'S List, Inc."},
#  {'label': 'health care medical/dental instruments',
#   'value': 'Angiodynamics, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Anworth Mortgage Asset Corporation'},
#  {'label': 'health care medical/dental instruments',
#   'value': 'Anika Therapeutics Inc.'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'Ansys, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Anthera Pharmaceuticals, Inc.'},
#  {'label': 'health care medical specialities', 'value': 'Anthem, Inc.'},
#  {'label': 'consumer services farming/seeds/milling',
#   'value': 'Alliance One International, Inc.'},
#  {'label': 'finance specialty insurers', 'value': 'Aon Plc'},
#  {'label': 'consumer durables consumer electronics/appliances',
#   'value': 'Smith (A.O.) Corporation'},
#  {'label': 'technology semiconductors',
#   'value': 'Alpha And Omega Semiconductor Limited'},
#  {'label': 'capital goods fluid controls',
#   'value': 'Ampco-Pittsburgh Corporation'},
#  {'label': 'energy oil & gas production', 'value': 'Apache Corporation'},
#  {'label': 'finance investment managers',
#   'value': 'Artisan Partners Asset Management Inc.'},
#  {'label': 'energy oil & gas production',
#   'value': 'Anadarko Petroleum Corporation'},
#  {'label': 'basic industries major chemicals',
#   'value': 'Air Products And Chemicals, Inc.'},
#  {'label': 'consumer services other consumer services',
#   'value': 'American Public Education, Inc.'},
#  {'label': 'capital goods electrical products',
#   'value': 'Amphenol Corporation'},
#  {'label': 'capital goods auto parts:o.e.m.',
#   'value': 'Apogee Enterprises, Inc.'},
#  {'label': 'health care medical/dental instruments',
#   'value': 'Accuray Incorporated'},
#  {'label': 'consumer services professional services',
#   'value': 'Arc Document Solutions, Inc.'},
#  {'label': 'consumer durables containers/packaging',
#   'value': 'Ardagh Group S.A.'},
# ...
#  {'label': 'consumer services broadcasting',
#   'value': 'Entravision Communications Corporation'},
#  {'label': 'finance investment managers', 'value': 'Evercore Partners Inc'},
#  {'label': 'technology edp services', 'value': 'Evertec, Inc.'},
#  {'label': 'health care industrial specialties',
#   'value': 'Edwards Lifesciences Corporation'},
#  {'label': 'finance major banks', 'value': 'East West Bancorp, Inc.'},
#  {'label': 'health care industrial specialties', 'value': 'Exactech, Inc.'},
#  {'label': 'health care biotechnology: commercial physical & biological resarch',
#   'value': 'Exact Sciences Corporation'},
#  {'label': 'public utilities power generation', 'value': 'Exelon Corporation'},
#  {'label': 'health care biotechnology: commercial physical & biological resarch',
#   'value': 'Exelixis, Inc.'},
#  {'label': 'miscellaneous business services',
#   'value': 'Exlservice Holdings, Inc.'},
#  {'label': 'capital goods building materials', 'value': 'Eagle Materials Inc'},
#  {'label': 'transportation oil refining/marketing',
#   'value': 'Expeditors International Of Washington, Inc.'},
#  {'label': 'consumer services transportation services',
#   'value': 'Expedia, Inc.'},
#  {'label': 'consumer services professional services',
#   'value': 'Exponent, Inc.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'Express, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Extra Space Storage Inc'},
#  {'label': 'technology computer communications equipment',
#   'value': 'Extreme Networks, Inc.'},
#  {'label': 'energy oil & gas production',
#   'value': 'Energy Xxi Gulf Coast, Inc.'},
#  {'label': 'consumer services other specialty stores',
#   'value': 'Ezcorp, Inc.'},
#  {'label': 'capital goods auto manufacturing', 'value': 'Ford Motor Company'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'First Acceptance Corporation'},
#  {'label': 'finance specialty insurers',
#   'value': 'First American Corporation (The)'},
#  {'label': 'technology computer software: prepackaged software',
#   'value': 'Falconstor Software, Inc.'},
#  {'label': 'energy oil & gas production', 'value': 'Diamondback Energy, Inc.'},
#  {'label': 'consumer non-durables packaged foods',
#   'value': 'Farmer Brothers Company'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Faro Technologies, Inc.'},
#  {'label': 'consumer services retail: building materials',
#   'value': 'Fastenal Company'},
#  {'label': 'technology computer software: programming, data processing',
#   'value': 'Facebook, Inc.'},
#  {'label': 'finance savings institutions', 'value': 'Flagstar Bancorp, Inc.'},
#  {'label': 'basic industries homebuilding',
#   'value': 'Fortune Brands Home & Security, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Bancorp'},
#  {'label': 'finance banks', 'value': 'First Connecticut Bancorp, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Bancorp.'},
#  {'label': 'basic industries paper', 'value': 'Fibria Celulose S.A.'},
#  {'label': 'consumer services other consumer services',
#   'value': 'Franklin Covey Company'},
#  {'label': 'finance major banks', 'value': 'First Community Bancshares, Inc.'},
#  {'label': 'miscellaneous industrial machinery/components',
#   'value': 'Fuelcell Energy, Inc.'},
#  {'label': 'finance major banks',
#   'value': 'First Commonwealth Financial Corporation'},
#  {'label': 'consumer services other specialty stores',
#   'value': 'First Cash, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Felcor Lodging Trust Incorporated'},
#  {'label': 'consumer services professional services',
#   'value': 'Fti Consulting, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Citizens Bancshares, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Fibrocell Science Inc'},
#  {'label': 'basic industries precious metals',
#   'value': 'Freeport-Mcmoran, Inc.'},
#  {'label': 'miscellaneous business services',
#   'value': 'First Data Corporation'},
#  {'label': 'finance savings institutions',
#   'value': 'First Defiance Financial Corp.'},
#  {'label': 'consumer non-durables farming/seeds/milling',
#   'value': 'Fresh Del Monte Produce, Inc.'},
#  {'label': 'technology computer software: programming, data processing',
#   'value': 'Factset Research Systems Inc.'},
#  {'label': 'transportation air freight/delivery services',
#   'value': 'Fedex Corporation'},
#  {'label': 'public utilities electric utilities: central',
#   'value': 'Firstenergy Corporation'},
#  {'label': 'consumer durables metal fabrications',
#   'value': 'Franklin Electric Co., Inc.'},
#  {'label': 'energy metal fabrications',
#   'value': 'Forum Energy Technologies, Inc.'},
#  {'label': 'basic industries major chemicals', 'value': 'Futurefuel Corp.'},
#  {'label': 'finance major banks', 'value': 'First Financial Bancorp.'},
#  {'label': 'finance life insurance', 'value': 'Fbl Financial Group, Inc.'},
#  {'label': 'finance major banks', 'value': 'Flushing Financial Corporation'},
#  {'label': 'finance major banks', 'value': 'First Financial Bankshares, Inc.'},
#  {'label': 'technology computer communications equipment',
#   'value': 'F5 Networks, Inc.'},
#  {'label': 'finance major banks', 'value': 'Farmers Capital Bank Corporation'},
#  {'label': 'finance major banks', 'value': 'First Financial Northwest, Inc.'},
#  {'label': 'basic industries specialty chemicals',
#   'value': 'Female Health Company (The)'},
#  {'label': 'finance major banks',
#   'value': 'First Horizon National Corporation'},
#  {'label': 'finance major banks',
#   'value': 'First Interstate Bancsystem, Inc.'},
#  {'label': 'miscellaneous business services',
#   'value': 'Fair Isaac Corporation'},
#  {'label': 'finance investment managers',
#   'value': 'Federated Investors, Inc.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'The Finish Line, Inc.'},
#  {'label': 'miscellaneous business services',
#   'value': 'Fidelity National Information Services, Inc.'},
#  {'label': 'finance major banks', 'value': 'Financial Institutions, Inc.'},
#  {'label': 'technology edp services', 'value': 'Fiserv, Inc.'},
#  {'label': 'finance major banks', 'value': 'Fifth Third Bancorp'},
#  {'label': 'consumer services department/specialty retail stores',
#   'value': 'Five Below, Inc.'},
#  {'label': 'capital goods engineering & construction',
#   'value': 'Comfort Systems Usa, Inc.'},
#  {'label': 'consumer non-durables beverages (production/distribution)',
#   'value': 'National Beverage Corp.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'Foot Locker, Inc.'},
#  {'label': 'capital goods biotechnology: laboratory analytical instruments',
#   'value': 'Fluidigm Corporation'},
#  {'label': 'technology electrical products', 'value': 'Flex Ltd.'},
#  {'label': 'finance major banks',
#   'value': 'The First Of Long Island Corporation'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Flir Systems, Inc.'},
#  {'label': 'consumer non-durables packaged foods',
#   'value': 'Flowers Foods, Inc.'},
#  {'label': 'technology industrial machinery/components',
#   'value': 'Spx Flow, Inc.'},
#  {'label': 'basic industries military/government/technical',
#   'value': 'Fluor Corporation'},
#  {'label': 'capital goods fluid controls', 'value': 'Flowserve Corporation'},
#  {'label': 'miscellaneous business services',
#   'value': 'Fleetcor Technologies, Inc.'},
#  {'label': 'consumer services other specialty stores',
#   'value': '1-800 Flowers.Com, Inc.'},
#  {'label': 'consumer durables home furnishings',
#   'value': 'Flexsteel Industries, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Midwest Bancorp, Inc.'},
#  {'label': 'basic industries major chemicals', 'value': 'Fmc Corporation'},
#  {'label': 'public utilities telecommunications equipment',
#   'value': 'Fabrinet'},
#  {'label': 'finance major banks', 'value': 'F.N.B. Corporation'},
#  {'label': 'finance specialty insurers',
#   'value': 'Fidelity National Financial, Inc.'},
#  {'label': 'finance investment managers', 'value': 'Financial Engines, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Bancorp, Inc (Me)'},
#  {'label': 'technology semiconductors', 'value': 'Finisar Corporation'},
#  {'label': 'basic industries paints/coatings', 'value': 'Ferro Corporation'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Amicus Therapeutics, Inc.'},
#  {'label': 'finance real estate', 'value': 'Forestar Group Inc'},
#  {'label': 'technology semiconductors', 'value': 'Formfactor, Inc.'},
#  {'label': 'consumer services diversified commercial services',
#   'value': 'Forrester Research, Inc.'},
#  {'label': 'consumer non-durables consumer specialties',
#   'value': 'Fossil Group, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'First Potomac Realty Trust'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'First Industrial Realty Trust, Inc.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': "Francesca'S Holdings Corporation"},
#  {'label': 'finance major banks', 'value': 'Republic First Bancorp, Inc.'},
#  {'label': 'consumer services department/specialty retail stores',
#   'value': "Fred'S, Inc."},
#  {'label': 'consumer services restaurants',
#   'value': 'Fiesta Restaurant Group, Inc.'},
#  {'label': 'finance major banks', 'value': 'First Merchants Corporation'},
#  {'label': 'transportation marine transportation', 'value': 'Frontline Ltd.'},
#  {'label': 'technology telecom services - domestic',
#   'value': 'Fairpoint Communications, Inc.'},
#  {'label': 'consumer non-durables packaged foods', 'value': 'Freshpet, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Federal Realty Investment Trust'},
#  {'label': 'finance major banks', 'value': 'First South Bancorp Inc'},
#  {'label': 'technology semiconductors', 'value': 'First Solar, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Franklin Street Properties Corp.'},
#  {'label': 'capital goods auto manufacturing',
#   'value': 'Federal Signal Corporation'},
#  {'label': 'basic industries metal fabrications',
#   'value': 'L.B. Foster Company'},
#  {'label': 'capital goods pollution control equipment',
#   'value': 'Fuel Tech, Inc.'},
#  {'label': 'energy metal fabrications', 'value': 'Technipfmc Plc'},
#  {'label': 'basic industries major chemicals',
#   'value': 'Flotek Industries, Inc.'},
#  {'label': 'technology computer peripheral equipment',
#   'value': 'Fortinet, Inc.'},
#  {'label': 'public utilities telecommunications equipment',
#   'value': 'Frontier Communications Corporation'},
#  {'label': 'basic industries home furnishings',
#   'value': 'H. B. Fuller Company'},
#  {'label': 'finance major banks', 'value': 'Fulton Financial Corporation'},
#  {'label': 'health care hospital/nursing management',
#   'value': 'Five Star Senior Living Inc.'},
#  {'label': 'transportation oil refining/marketing',
#   'value': 'Forward Air Corporation'},
#  {'label': 'consumer services professional services',
#   'value': 'Genpact Limited'},
#  {'label': 'finance major banks', 'value': 'German American Bancorp, Inc.'},
#  {'label': 'consumer services movies/entertainment', 'value': 'Gaia, Inc.'},
#  {'label': 'health care major pharmaceuticals',
#   'value': 'Galena Biopharma, Inc.'},
#  {'label': 'finance major banks', 'value': 'Glacier Bancorp, Inc.'},
#  {'label': 'finance investment bankers/brokers/service',
#   'value': 'Gamco Investors, Inc.'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Global Indemnity Limited'},
#  {'label': 'finance major banks', 'value': 'Guaranty Bancorp'},
#  {'label': 'capital goods railroads',
#   'value': 'Greenbrier Companies, Inc. (The)'},
#  {'label': 'finance investment bankers/brokers/service',
#   'value': 'Gain Capital Holdings, Inc.'},
#  {'label': 'consumer services newspapers/magazines', 'value': 'Tegna Inc.'},
#  {'label': 'consumer services clothing/shoe/accessory stores',
#   'value': 'Genesco Inc.'},
#  {'label': 'capital goods marine transportation',
#   'value': 'General Dynamics Corporation'},
#  {'label': 'technology industrial machinery/components',
#   'value': 'Gardner Denver Holdings, Inc.'},
#  {'label': 'finance finance: consumer services',
#   'value': 'Green Dot Corporation'},
#  {'label': 'energy oil & gas production',
#   'value': 'Goodrich Petroleum Corporation'},
#  {'label': 'energy consumer electronics/appliances',
#   'value': 'General Electric Company'},
#  {'label': 'health care hospital/nursing management',
#   'value': 'Genesis Healthcare, Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Geo Group Inc (The)'},
#  {'label': 'capital goods industrial machinery/components',
#   'value': 'Geospace Technologies Corporation'},
#  {'label': 'health care major pharmaceuticals', 'value': 'Geron Corporation'},
#  {'label': 'consumer non-durables apparel', 'value': 'Guess, Inc.'},
#  {'label': 'basic industries major chemicals', 'value': 'Gevo, Inc.'},
#  {'label': 'capital goods building products', 'value': 'Griffon Corporation'},
#  {'label': 'capital goods fluid controls', 'value': 'Graco Inc.'},
#  {'label': 'consumer services real estate investment trusts',
#   'value': 'Ggp Inc.'},
#  {'label': 'health care medical specialities',
#   'value': 'Genomic Health, Inc.'},
#  {'label': 'finance investment bankers/brokers/service',
#   'value': 'Greenhill & Co., Inc.'},
#  {'label': 'technology industrial machinery/components',
#   'value': 'Graham Corporation'},
#  {'label': 'capital goods metal fabrications',
#   'value': 'Gulf Island Fabrication, Inc.'},
#  {'label': 'consumer non-durables apparel',
#   'value': 'G-Iii Apparel Group, Ltd.'},
#  {'label': 'health care biotechnology: biological products (no diagnostic substances)',
#   'value': 'Gilead Sciences, Inc.'},
#  {'label': 'consumer non-durables packaged foods',
#   'value': 'General Mills, Inc.'},
#  {'label': 'public utilities electric utilities: central',
#   'value': 'Terraform Global, Inc.'},
#  {'label': 'financial investment brokerage - regional',
#   'value': 'Gleacher & Company, Inc.'},
#  {'label': 'basic industries military/government/technical',
#   'value': 'Great Lakes Dredge & Dock Corporation'},
#  {'label': 'consumer services marine transportation',
#   'value': 'Golar Lng Limited'},
#  {'label': 'consumer services marine transportation', 'value': 'Gaslog Lp.'},
#  {'label': 'industrial goods diversified machinery',
#   'value': 'Global Power Equipment Group In'},
#  {'label': 'finance property-casualty insurers',
#   'value': 'Greenlight Reinsurance, Ltd.'},
#  {'label': 'basic industries paper', 'value': 'Glatfelter'},
#  {'label': 'technology edp services', 'value': 'Glu Mobile Inc.'},
#  {'label': 'basic industries telecommunications equipment',
#   'value': 'Corning Incorporated'},
#  {'label': 'capital goods auto manufacturing',
#   'value': 'General Motors Company'},
#  {'label': 'consumer services electronics distribution',
#   'value': 'Gamestop Corporation'},
#  {'label': 'health care medical/dental instruments',
#   'value': 'Globus Medical, Inc.'},
#  {'label': 'basic materials oil & gas drilling & exploration',
#   'value': 'Geomet, Inc.'},
#  {'label': 'basic industries precious metals', 'value': 'General Moly, Inc'},
#  {'label': 'consumer non-durables food chains', 'value': 'Gnc Holdings, Inc.'},
#  {'label': 'public utilities telecommunications equipment',
#   'value': 'General Communication, Inc.'},
#  {'label': 'public utilities power generation', 'value': 'Genie Energy Ltd.'},
#  {'label': 'transportation marine transportation',
#   'value': 'Genco Shipping & Trading Limited Warrants Expiring 12/31/2021'},
#  {'label': 'health care medical/dental instruments',
#   'value': 'Genmark Diagnostics, Inc.'},
#  {'label': 'consumer durables metal fabrications',
#   'value': 'Generac Holdlings Inc.'},
#  {'label': 'capital goods auto parts:o.e.m.', 'value': 'Gentex Corporation'},
#  {'label': 'finance life insurance', 'value': 'Genworth Financial Inc'},
#  {'label': 'consumer services real estate',
#   'value': 'Gladstone Commercial Corporation'},
#  {'label': 'technology computer software: programming, data processing',
#   'value': 'Alphabet Inc.'},
#  ...]

# %%
dfrussel=pd.read_csv(locrussellanddata,index_col='Symbol')
stocks_info_df = pd.read_csv(locsp500anddata,index_col='tickers')

# %%
tickers=[]
if(analyse_sp_or_russell =='russell'):
    tickers= dfrussel.index
else:
    tickers= stocks_info[0]    

    
tickers=[x for x in tickers if x not in blacklist]
tickersshort = tickers[:10]
tickersmedium = tickers[:50]
tickersmediumlarge = tickers[:300]

# %% [markdown]
# # Getting lists of current stocks prices and give limitations

# %%
days_per_year = 365.24
start = datetime.datetime.now()-datetime.timedelta(days=1)
end = datetime.datetime.now()

def cheapstockspriceunderprice(price = 20,n_random_sample=100, asc = True):
    rand_smpl = [ tickers[i] for i in sorted(random.sample(xrange(len(tickers)), n_random_sample)) ]
    
    print rand_smpl
    
    dfcomp = web.DataReader(rand_smpl,'yahoo',
                                   start=start, 
                                   end=end)['Close'].T

    dfcomp.columns =['stocksprice']
    dfcompfilters = dfcomp[dfcomp.stocksprice<price]
    dfcompsorted = dfcompfilters.sort_values('stocksprice',ascending=asc)
    return dfcompsorted

# %%
from datetime import datetime as dt
frame = web.DataReader(
        'goog', data_source='google',
        start=dt(2012, 1, 1), end=dt.now())
frame['year'] = pd.DatetimeIndex(frame.index).year
gframe = frame.groupby('year').head(1)
gframe.set_index('year')['Close'].min()
# Out:
# 332.37

# %%
dfcompsorted = cheapstockspriceunderprice(20,100,True)
# Out:
# [u'ACC', u'ACTL', u'AES', u'AGX', u'ALSK', u'ANAT', u'ARNA', u'ATHN', u'ATR', u'AVB', u'BEN', u'CAG', u'CBB', u'CGA', u'CHCO', u'CMCO', u'CMCSA', u'CNK', u'CSOD', u'CUTR', u'CVGI', u'DFT', u'DIOD', u'DOW', u'EGY', u'EPC', u'EPM', u'EQT', u'EWBC', u'FDX', u'G', u'GD', u'GDI', u'GE', u'GEOS', u'GSBC', u'H', u'HAYN', u'HBIO', u'HLS', u'HRL', u'IRBT', u'KBH', u'KMG', u'KMX', u'LNC', u'LOGM', u'LORL', u'MDCA', u'MHLD', u'MHO', u'MRIN', u'MTW', u'NECB', u'NFBK', u'NTCT', u'OLED', u'ORIT', u'PAYX', u'PCRX', u'PDFS', u'PEI', u'PETS', u'PKY', u'PMT', u'PROV', u'PRXL', u'PSMT', u'PZN', u'RAIL', u'RGR', u'RRD', u'RRGB', u'RSG', u'SALM', u'SCSS', u'SCVL', u'SGYP', u'SMG', u'SNBC', u'SO', u'STRS', u'SXC', u'TBBK', u'TEAR', u'TFSL', u'TSO', u'UMH', u'USPH', u'VSH', u'VVUS', u'WIN', u'WLH', u'WMGI', u'WRI', u'WSBC', u'WSM', u'WU', u'WYN', u'ZTS']
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ACC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ACTL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'AES', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'AGX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ALSK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ANAT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ARNA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ATHN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ATR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'AVB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'BEN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CAG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CBB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CGA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CHCO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CMCO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CMCSA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CNK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CSOD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CUTR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'CVGI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'DFT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'DIOD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'DOW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'EGY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'EPC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'EPM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'EQT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'EWBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'FDX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'G', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'GD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'GDI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'GE', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'GEOS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'GSBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'H', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'HAYN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'HBIO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'HLS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'HRL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'IRBT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'KBH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'KMG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'KMX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'LNC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'LOGM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'LORL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'MDCA', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'MHLD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'MHO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'MRIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'MTW', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'NECB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'NFBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'NTCT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'OLED', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ORIT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PAYX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PCRX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PDFS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PEI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PETS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PKY', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PROV', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PRXL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PSMT', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'PZN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'RAIL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'RGR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'RRD', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'RRGB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'RSG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SALM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SCSS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SCVL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SGYP', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SMG', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SNBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'STRS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'SXC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'TBBK', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'TEAR', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'TFSL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'TSO', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'UMH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'USPH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'VSH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'VVUS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WIN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WLH', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WMGI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WRI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WSBC', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WSM', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WU', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'WYN', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.py:136: SymbolWarning: Failed to read symbol: u'ZTS', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-13-fc353e5ffa74> in <module>()
# ----> 1 dfcompsorted = cheapstockspriceunderprice(20,100,True)
#
# <ipython-input-11-49b8d602a883> in cheapstockspriceunderprice(price, n_random_sample, asc)
#      10     dfcomp = web.DataReader(rand_smpl,'yahoo',
#      11                                    start=start,
# ---> 12                                    end=end)['Close'].T
#      13
#      14     dfcomp.columns =['stocksprice']
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\data.pyc in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     119                                 adjust_price=False, chunksize=25,
#     120                                 retry_count=retry_count, pause=pause,
# --> 121                                 session=session).read()
#     122
#     123     elif data_source == "yahoo-actions":
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.pyc in read(self)
#     113         """ read one data from specified URL """
#     114         try:
# --> 115             df = super(YahooDailyReader, self).read()
#     116             if self.ret_index:
#     117                 df['Ret_Index'] = _calc_return_index(df['Adj Close'])
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\base.pyc in read(self)
#     184             df = self._dl_mult_symbols(self.symbols.index)
#     185         else:
# --> 186             df = self._dl_mult_symbols(self.symbols)
#     187         return df
#     188
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas_datareader\yahoo\daily.pyc in _dl_mult_symbols(self, symbols)
#     139         if len(passed) == 0:
#     140             msg = "No data fetched using {0!r}"
# --> 141             raise RemoteDataError(msg.format(self.__class__.__name__))
#     142         try:
#     143             if len(stocks) > 0 and len(failed) > 0 and len(passed) > 0:
#
# RemoteDataError: No data fetched using 'YahooDailyReader'

# %%
dfcompsorted

# %% [markdown]
# ## Scraping marketwatch Data Using Beautiful Soup

# %% [markdown]
# ### Formatting all the values to numerical

# %%
def format(list):
    newlist=[]
    posornegnumber = 1
    for text in list:
        if text.endswith(')'):
            text = text[1:-1] # remove the parentheses
            posornegnumber = -1
            
        if text.endswith('%'):
#             Then please make it into comma float
            endtext = float(text[:-1])/100.0 * posornegnumber 
        elif text.endswith('B'):
#             Then please times 1000000000
#             Change it into integer
            endtext = int(float(text[:-1])*1000000000)* posornegnumber 
        elif text.endswith('M'):
#             Then please times 1000000
#             Change it into integer
            endtext = int(float(text[:-1])*1000000)* posornegnumber 
        elif ',' in text:
#             Then please remove the ,
#             Then change it into int
            endtext = int(float(text.replace(",","")))* posornegnumber 

        elif text.endswith('-'):
#             Insert 0
            endtext = 0
        else:
#             change to float
            endtext = float(text)* posornegnumber 
        newlist.append(endtext)
    return newlist

# %% [markdown]
# ### Extracting Financial Reporting (Balance Sheet and Income Statement)

# %%
# %%time
import pandas as pd
from urllib import urlopen
from bs4 import BeautifulSoup

dflist = []
tickersnotfound =[] 
counter = 0

for ticker in dfcompsorted.index: 
    try:
        urlfinancials = urlmarketwatch+ticker+'/financials'
        urlbalancesheet = urlmarketwatch+ticker+'/financials/balance-sheet'

        text_soup_financials = BeautifulSoup(urlopen(urlfinancials).read()) #read in
        text_soup_balancesheet = BeautifulSoup(urlopen(urlbalancesheet).read()) #read in

        # Income statement
        titlesfinancials = text_soup_financials.findAll('td', {'class': 'rowTitle'})
        epslist=[]
        netincomelist = []
        longtermdebtlist = [] 
        interestexpenselist = []
        ebitdalist= []

        for title in titlesfinancials:
            if 'EPS (Basic)' in title.text:
                epslist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Net Income' in title.text:
                netincomelist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Interest Expense' in title.text:
                interestexpenselist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'EBITDA' in title.text:
                ebitdalist.append ([td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])


        # Balance sheet
        titlesbalancesheet = text_soup_balancesheet.findAll('td', {'class': 'rowTitle'})
        equitylist=[]
        for title in titlesbalancesheet:
            if 'Total Shareholders\' Equity' in title.text:
                equitylist.append( [td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])
            if 'Long-Term Debt' in title.text:
                longtermdebtlist.append( [td.text for td in title.findNextSiblings(attrs={'class': 'valueCell'}) if td.text])

        # Variables        
        eps = epslist[0]
        epsgrowth = epslist[1]
        netincome = netincomelist[0]
        shareholderequity = equitylist[0]
        roa = equitylist[1]

        longtermdebt = longtermdebtlist[0]
        interestexpense = interestexpenselist[0]
        ebitda = ebitdalist[0]
        # Don't forget to add in roe, interest coverage ratio

        ## Make it into Dataframes
        df= pd.DataFrame({'eps': eps,'epsgrowth': epsgrowth,'netincome': netincome,'shareholderequity': shareholderequity,'roa': 
                      roa,'longtermdebt': longtermdebt,'interestexpense': interestexpense,'ebitda': ebitda},index=[2012,2013,2014,2015,2016])

        # Format all the number in dataframe
        dfformatted = df.apply(format)

        # Adding roe, interest coverage ratio
        dfformatted['roe'] = dfformatted.netincome/dfformatted.shareholderequity
        dfformatted['interestcoverageratio'] = dfformatted.ebitda/dfformatted.interestexpense

    #     Insert ticker and df
        dflist.append((ticker,dfformatted))
        
        counter+=1
        print(ticker, ' has been processed')
    except:
        tickersnotfound.append(ticker)
        print(ticker,' ticker is not found')
# Out:
# ('SYMX', ' has been processed')
# ('HUSA', ' has been processed')
# ('STXS', ' has been processed')
# ('MRIN', ' has been processed')
# ('GROW', ' ticker is not found')
# ('GEN', ' ticker is not found')
# ('UEC', ' has been processed')
# ('PQ', ' ticker is not found')
# ('ALSK', ' has been processed')
# ('SNSS', ' has been processed')
# ('PRTS', ' has been processed')
# ('GVP', ' ticker is not found')
# ('BTX', ' has been processed')
# ('BWEN', ' has been processed')
# ('ALO', ' ticker is not found')
# ('EVC', ' has been processed')
# ('NPTN', ' ticker is not found')
# ('BDE', ' ticker is not found')
# ('HALL', ' ticker is not found')
# ('ENZ', ' ticker is not found')
# ('SFE', ' ticker is not found')
# ('THC', ' ticker is not found')
# ('MLP', ' ticker is not found')
# ('BKE', ' has been processed')
# ('SHBI', ' ticker is not found')
# ('HSC', ' ticker is not found')
# ('OSTK', ' has been processed')
# ('FC', ' has been processed')
# ('CVI', ' has been processed')
# ('HT', ' ticker is not found')
# ('EXXI', ' ticker is not found')
# Wall time: 2min 7s

# %%
# Inputting the failed to the not to be processed subsequently.
stickersnotfound = ','+','.join(map(str, tickersnotfound)) 
with open(locblacklist,'ab') as f:
        f.write(stickersnotfound )

# %%
dflist[0][1].reset_index()
# Out:
#    index    ebitda   eps  epsgrowth  interestexpense  longtermdebt  netincome  \
# 0   2012 -14980000 -0.39     0.0000           562000       2370000  -20070000
# 1   2013 -15090000 -0.33     0.1538           302000             0  -19920000
# 2   2014 -12030000 -0.22     0.3333           381000             0  -14000000
# 3   2015 -15760000 -0.50    -1.2727           372000             0  -38540000
# 4   2016 -13050000 -0.27     0.4600           439000             0  -23590000
#
#       roa  shareholderequity       roe  interestcoverageratio
# 0  0.8709           80860000 -0.248207             -26.654804
# 1  0.8962           79190000 -0.251547             -49.966887
# 2  0.8934           81930000 -0.170878             -31.574803
# 3  0.8110           59810000 -0.644374             -42.365591
# 4  0.7565           41740000 -0.565165             -29.726651

# %%
len(dflist)
# Out:
# 15

# %% [markdown]
# #### Pickle for writing

# %%
filehandler = open(locfinancialreportpickle, 'w') 
pickle.dump(dflist, filehandler)

# %% [markdown]
# #### Pickle for Reading

# %%
filehandler = open(locfinancialreportpickle, 'r') 
dflist = pickle.load(filehandler)

# %% [markdown]
# ## Determining legibility
# Find whether this particular stocks is legitimate using this and filter accordingly
#     1. EPS increases over the year (consistent)
#     2. ROE > 0.15
#     3. ROA > 0.07 (also consider debt to equity cause Assets = liabilities + equity)
#     4. Long term debt < 5 * income
#     5. Interest Coverage Ratio > 3

# %%
def eligibilitycheck(df):
    ticker,dfformatted = df
    
    legiblestock = True
    reasonlist=[]

    # EPS increases over the year (consistent)
#     Counting 2 or more negative growth
    countnegativegrowth =0
    for growth in dfformatted.epsgrowth:
        if growth<0:
            countnegativegrowth+=1
        if countnegativegrowth>=3:
            legiblestock = False
            reasonlist.append('there are 2 negative growth '+str(growth))
            break
    # ROE > 0.15
    if dfformatted.roe.mean()<0.15:
            legiblestock = False
            reasonlist.append('roe mean is less than 0.13 '+ str(dfformatted.roe.mean()))
    # ROA > 0.07 (also consider debt to equity cause Assets = liabilities + equity)
    if dfformatted.roa.mean()<0.07:
            legiblestock = False
            reasonlist.append('roa mean is less than 0.07 ' + str(dfformatted.roa.mean()))
    # Long term debt < 5 * income
    if dfformatted.longtermdebt.tail(1).values[0]>5*dfformatted.netincome.tail(1).values[0]:
            legiblestock = False
            reasonlist.append('longtermdebt is 5 times the netincome ')
    # Interest Coverage Ratio > 3
    if dfformatted.interestcoverageratio.tail(1).values[0]<3:
            legiblestock = False
            reasonlist.append('Interestcoverageratio is less than 3 ')
#     print ticker,legiblestock,reasonlist
    return ticker,legiblestock

# %%
selectiondflist = []
for df in dflist:
    if eligibilitycheck(df)[1]:
        selectiondflist.append(df)

# %%
len(dflist)
# Out:
# 15

# %%
len(selectiondflist)
# Out:
# 1

# %%
if(not filter_applies):
    selectiondflist = dflist

# %%
# What are the tickers of these?
tickersselections = [x[0] for x in selectiondflist]

# %%
tickersselections
# Out:
# ['OSTK']

# %% [markdown]
# ## Scraping for latest shareprice using selectiondflist

# %%
selecteddfcomp = dfcompsorted[dfcompsorted.index.isin(tickersselections)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-8686eff6a80f> in <module>()
# ----> 1 selecteddfcomp = dfcompsorted[dfcompsorted.index.isin(tickersselections)]
#
# NameError: name 'dfcompsorted' is not defined

# %% [markdown]
# # Using selectiondflist to calculate stocks price value
#
# Outputs:
# 1. Ranking of each company in terms of return rate given the value investing methodology
#     a. Find EPS Annual Compounded Growth Rate
#     b. Estimate EPS 10 years from now
#     c. Estimate stock price 10 years from now (Stock Price EPS * Average PE)
#     d. Determine target by price today based on returns(discount rate 15%/20%)
#     e. Add margin of safety (Safety net 15%)

# %%
for tuple in selectiondflist:
    ticker, df = tuple
    
    # Find EPS Annual Compounded Growth Rate
    annualgrowthrate =  df.epsgrowth.mean() #growth rate
    
    # Estimate stock price 10 years from now (Stock Price EPS * Average PE)
    lasteps = df.eps.tail(1).values[0] #presentvalue
    years  = 10 #period
    
    futureeps = abs(np.fv(annualgrowthrate,years,0,lasteps))
        
    dfprice.loc[i] = [ticker,annualgrowthrate,lasteps,futureeps]
    i+=1
    
dfprice.set_index('ticker',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b6af72249529> in <module>()
#       9     years  = 10 #period
#      10
# ---> 11     futureeps = abs(np.fv(annualgrowthrate,years,0,lasteps))
#      12
#      13     dfprice.loc[i] = [ticker,annualgrowthrate,lasteps,futureeps]
#
# NameError: name 'np' is not defined

# %%
dfprice['lastshareprice']=selecteddfcomp.stocksprice
dfprice['peratio'] = dfprice['lastshareprice']/dfprice['lasteps']
dfprice['futureshareprice'] = dfprice['futureeps']*dfprice['peratio']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-0bd1c2510686> in <module>()
# ----> 1 dfprice['lastshareprice']=selecteddfcomp.stocksprice
#       2 dfprice['peratio'] = dfprice['lastshareprice']/dfprice['lasteps']
#       3 dfprice['futureshareprice'] = dfprice['futureeps']*dfprice['peratio']
#
# NameError: name 'selecteddfcomp' is not defined

# %%
discountrate = 0.2
margin = 0.15

dfprice['discshareprice'] = abs(np.pv(discountrate,years,0,fv=dfprice['futureshareprice']))
dfprice['marginalizedprice'] = dfprice['discshareprice']*(1-0.15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-659c7b84fa33> in <module>()
#       2 margin = 0.15
#       3
# ----> 4 dfprice['discshareprice'] = abs(np.pv(discountrate,years,0,fv=dfprice['futureshareprice']))
#       5 dfprice['marginalizedprice'] = dfprice['discshareprice']*(1-0.15)
#
# NameError: name 'np' is not defined

# %%
dfprice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-81b71541ef73> in <module>()
# ----> 1 dfprice
#
# NameError: name 'dfprice' is not defined

# %%
mergestocksdf = pd.merge(stocks_info_df, dfprice, how='inner', left_index=True,right_index=True)

# %%
mergestocksdf['Buy'] = mergestocksdf.lastshareprice<=mergestocksdf.marginalizedprice
mergestocksdf['newsurl'] = 'http://www.cnbc.com/quotes/?symbol='+mergestocksdf.index
mergestocksdf['dividendhistoryurl'] = 'http://www.nasdaq.com/symbol/'+mergestocksdf.index+'/dividend-history'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-244-1d353ce9efff> in <module>()
#       1 mergestocksdf['Buy'] = mergestocksdf.lastshareprice<=mergestocksdf.marginalizedprice
#       2 mergestocksdf['newsurl'] = 'http://www.cnbc.com/quotes/?symbol='+mergestocksdf.index
# ----> 3 mergestocksdf['dividendhistoryurl'] = 'http://www.nasdaq.com/symbol/'+mergestocksdf.index+'/dividend-history'
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\indexes\range.pyc in _evaluate_numeric_binop(self, other)
#     558             def _evaluate_numeric_binop(self, other):
#     559
# --> 560                 other = self._validate_for_numeric_binop(other, op, opstr)
#     561                 attrs = self._get_attributes_dict()
#     562                 attrs = self._maybe_update_attributes(attrs)
#
# C:\Users\vintatan\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\indexes\base.pyc in _validate_for_numeric_binop(self, other, op, opstr)
#    3792         else:
#    3793             if not (is_float(other) or is_integer(other)):
# -> 3794                 raise TypeError("can only perform ops with scalar values")
#    3795
#    3796         return other
#
# TypeError: can only perform ops with scalar values

# %%
mergestocksdf.head()

# %%
mergestocksdf.to_csv(locstocksanalysis)

# %%
mergestocksdf[mergestocksdf.Buy==True].sort_values('marginalizedprice',ascending=True)
